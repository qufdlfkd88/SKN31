# %% [markdown]
# # 성능개선 기법 실습

# %% [markdown]
# # 모듈 정의

# %% [markdown]
# ## train.py
#
# -   모델 학습과 검증 함수 정의

# %%
import os

os.makedirs("module", exist_ok=True)

# %%
# %%writefile module/train.py

import torch
import time

def test_multi_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    다중 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() 
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad(): #gradiant 계산 필요없음
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            # 정확도 계산
            pred_label = torch.argmax(pred, axis=-1)
            test_accuracy += torch.sum(pred_label == y).item()
            
        test_loss /= num_steps
        test_accuracy /= size   # 전체 개수로 나눔
    return test_loss, test_accuracy

def test_binary_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    이진 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() # 모델을 평가모드로 변환
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            ## 정확도 계산
            pred_label = (pred >= 0.5).type(torch.int32)
            test_accuracy += (pred_label == y).sum().item() 
            
        test_loss /= num_steps
        test_accuracy /= size   #전체 개수로 나눈다.
    return test_loss, test_accuracy    

def train(dataloader, model, loss_fn, optimizer, device="cpu", mode:"binary or multi"='binary'):
    """
    모델을 1 epoch 학습시키는 함수

    Args:
        dataloader: DataLoader - 학습데이터셋을 제공하는 DataLoader
        model - 학습대상 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        optimizer - 최적화 함수
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
        mode: str - 분류 종류. binary 또는 multi
    
    Returns:
        tuple: 학습후 계산한 Train set에 대한  train_loss, train_accuracy
    """
    model.train()
    size = len(dataloader.dataset) # 총 데이터포인트 개수

    for X, y in dataloader:
        # 1. DEVICE로 이동동
        X, y = X.to(device), y.to(device)
        # 2. 모델 추정
        pred = model(X)
        # 3. loss 계산
        loss = loss_fn(pred, y)
        # 4. gradient 초기화
        optimizer.zero_grad()
        # 5. gradient 계산
        loss.backward()
        # 6. 파라미터 업데이트트
        optimizer.step()
        
    if mode == 'binary':
        train_loss, train_accuracy = test_binary_classification(dataloader, model, loss_fn, device)
    else:
        train_loss, train_accuracy = test_multi_classification(dataloader, model, loss_fn, device)
    return train_loss, train_accuracy



def fit(train_loader, val_loader, model, loss_fn, optimizer, epochs, save_best_model=True, 
        save_model_path=None, early_stopping=True, patience=10, device='cpu',  mode:"binary or multi"='binary',
        lr_scheduler=None): # early_stopping = False 면 patience는 필요가 없음
    """
    모델을 학습시키는 함수

    Args:
        train_loader (Dataloader): Train dataloader
        test_loader (Dataloader): validation dataloader
        model (Module): 학습시킬 모델
        loss_fn (_Loss): Loss function
        optimizer (Optimizer): Optimizer
        epochs (int): epoch수
        save_best_model (bool, optional): 학습도중 성능개선시 모델 저장 여부. Defaults to True.
        save_model_path (str, optional): save_best_model=True일 때 모델저장할 파일 경로. Defaults to None.
        early_stopping (bool, optional): 조기 종료 여부. Defaults to True.
        patience (int, optional): 조기종료 True일 때 종료전에 성능이 개선될지 몇 epoch까지 기다릴지 epoch수. Defaults to 10.
        device (str, optional): device. Defaults to 'cpu'.
        mode(str, optinal): 분류 종류. "binary(default) or multi
        lr_scheduler: Learning Rate Scheduler 객체. default: None, Epoch 단위로 LR 를 변경.
    
    Returns:
        tuple: 에폭 별 성능 리스트. (train_loss_list, train_accuracy_list, validation_loss_list, validataion_accuracy_list)
    """

    train_loss_list = []
    train_accuracy_list = []
    val_loss_list = []
    val_accuracy_list = []
    
        
    if save_best_model:
        best_score_save = torch.inf

    ############################
    # early stopping
    #############################
    if early_stopping:
        trigger_count = 0
        best_score_es = torch.inf
    
    # 모델 device로 옮기기
    model = model.to(device)
    s = time.time()
    for epoch in range(epochs):
        # train() 호출 -> 1 epoch 학습. train loss, accuracy 반환.
        train_loss, train_accuracy = train(train_loader, model, loss_fn, optimizer, device=device, mode=mode)
        
        ############ 1 epoch 학습 종료 -> Learning Rate 를 변경 ###########
        if lr_scheduler is not None:
            current_lr = lr_scheduler.get_last_lr()[0]  # log용
            lr_scheduler.step()
            new_lr = lr_scheduler.get_last_lr()[0] # log용
            if current_lr != new_lr: # LR가 변경되었으면
                print(f">>>>>>Learning Rate가 {current_lr}에서 {new_lr}로 변경됨<<<<<<")

        # test() 함수 호출해서 1epoch 학습한 것에 대해 검증.
        if mode == "binary":
            val_loss, val_accuracy = test_binary_classification(val_loader, model, loss_fn, device=device)
        else:
            val_loss, val_accuracy = test_multi_classification(val_loader, model, loss_fn, device=device)

        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        val_loss_list.append(val_loss)
        val_accuracy_list.append(val_accuracy)
        
        print(f"Epoch[{epoch+1}/{epochs}] - Train loss: {train_loss:.5f} Train Accucracy: {train_accuracy:.5f} || Validation Loss: {val_loss:.5f} Validation Accuracy: {val_accuracy:.5f}")
        print('='*100)
        
        # 모델 저장
        if save_best_model:
            if val_loss < best_score_save:  # loss는 적어야 좋은 것이기 때문에 best_score_save 이 크면 개선이 된것
                torch.save(model, save_model_path)
                print(f"저장: {epoch+1} - 이전 : {best_score_save}, 현재: {val_loss}")
                best_score_save = val_loss
        
        # early stopping 처리            
        if early_stopping:
            if val_loss < best_score_es: # 성능 개선
                best_score_es = val_loss  
                trigger_count = 0
                                
            else:   # 성능 개선 안됨
                trigger_count += 1                
                if patience == trigger_count: # patience가 10이기에 10번동안 개선이 안되면 멈춤
                    print(f"Early stopping: Epoch - {epoch}")
                    break
            
    e = time.time()
    print(e-s, "초")
    return train_loss_list, train_accuracy_list, val_loss_list, val_accuracy_list
# Out:
# Writing module/train.py

# %% [markdown]
# ## data.py
#
# -   dataset 생성 함수 제공 모듈

# %%
# %%writefile module/data.py

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def load_mnist_dataset(root_path, batch_size, is_train=True):
    """
    mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader 
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.MNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader

def load_fashion_mnist_dataset(root_path, batch_size, is_train=True):
    """
    fashion mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.FashionMNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader
# Out:
# Writing module/data.py

# %% [markdown]
# ## utils.py

# %%
# %%writefile module/utils.py
# 학습 결과를 시각화하는 함수.
import matplotlib.pyplot as plt

def plot_fit_result(train_loss_list, train_accuracy_list, valid_loss_list, valid_accuracy_list):
    """epoch별 학습 결과를 시각화하는 함수
    epoch별 loss와 accuracy를 시각화한다.

    Args:
        train_loss_list (list): Epoch별 train loss
        train_accuracy_list (list): Epoch별 train accuracy
        valid_loss_list (list): Epoch별 validation loss
        valid_accuracy_list (list): Epoch별 validation accuracy
    """
    epoch = len(train_loss_list)
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(range(epoch), train_loss_list, label="train loss")
    plt.plot(range(epoch), valid_loss_list, label="validation loss")
    plt.title("Loss")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(epoch), train_accuracy_list, label="train accuracy")
    plt.plot(range(epoch), valid_accuracy_list, label="validation accuracy")
    plt.title("Accuracy")
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Writing module/utils.py

# %% [markdown]
# ## Import

# %%
import torch
import torch.nn as nn
from torchinfo import summary

from module.train import fit
from module.data import load_mnist_dataset, load_fashion_mnist_dataset
from module.utils import plot_fit_result

# %% [markdown]
# ## 하이퍼파라미터, 변수 정의

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
root_data_path = "datasets"

epochs = 100
batch_size = 256
lr = 0.001

# %% [markdown]
# # Data 준비
#
# ## mnist 데이터 로딩

# %%
train_loader = load_mnist_dataset(root_data_path, batch_size)
test_loader = load_mnist_dataset(root_data_path, batch_size, False)

## Fashion Mnist
# train_loader = load_fashion_mnist_dataset(root_data_path, batch_size)
# test_loader = load_fashion_mnist_dataset(root_data_path, batch_size, False)

# %%
classes = train_loader.dataset.classes
class_to_idx = train_loader.dataset.class_to_idx

# %%
print(classes)
print(class_to_idx)
# Out:
# ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four', '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']
# {'0 - zero': 0, '1 - one': 1, '2 - two': 2, '3 - three': 3, '4 - four': 4, '5 - five': 5, '6 - six': 6, '7 - seven': 7, '8 - eight': 8, '9 - nine': 9}

# %% [markdown]
# # 모델의 크기 변경에 따른 성능변화
# ## 작은 모델

# %%
class SmallModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lr = nn.Linear(28*28, 10) # 입력 -> 출력  #  self.lr2 = nn.Linear(16, 10) 만 넣어도 성능이 0.96 정도로 개선됨.

    def forward(self, X):
        X = nn.Flatten()(X)
        out = self.lr(X)
        return out

# %%
small_model = SmallModel().to(device)
summary(small_model, (100, 1, 28, 28), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SmallModel                               [100, 10]                 --
# ├─Linear: 1-1                            [100, 10]                 7,850
# ==========================================================================================
# Total params: 7,850
# Trainable params: 7,850
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.79
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.03
# Estimated Total Size (MB): 0.35
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss() # 다중분류의 loss 함수
optimizer = torch.optim.Adam(small_model.parameters(), lr=lr)

lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,   # 변화주기 (step/epoch) 최소(eta_min) <-> 최대(초기 lr)
    T_mult=2, # 새로운 변화주기(T_0) = 현재 T_O * T_mult (한 주기가 끝날때마다 T_O를 다시 계산.)
    eta_min=1e-6 # 0.000001
)

# %%
train_loss_list, train_acc_list, valid_loss_list, valid_acc_list = fit(
    train_loader, 
    test_loader,
    small_model, 
    loss_fn, 
    optimizer,
    epochs,
    save_best_model=False,
    device=device,
    mode="multi"
)
# Out:
# Epoch[1/100] - Train loss: 0.48344 Train Accucracy: 0.88125 || Validation Loss: 0.46139 Validation Accuracy: 0.88970
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.37931 Train Accucracy: 0.89897 || Validation Loss: 0.36119 Validation Accuracy: 0.90550
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.33822 Train Accucracy: 0.90828 || Validation Loss: 0.32226 Validation Accuracy: 0.91180
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.31563 Train Accucracy: 0.91345 || Validation Loss: 0.30295 Validation Accuracy: 0.91520
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.30138 Train Accucracy: 0.91758 || Validation Loss: 0.29188 Validation Accuracy: 0.91820
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.29152 Train Accucracy: 0.91922 || Validation Loss: 0.28318 Validation Accuracy: 0.92040
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.28386 Train Accucracy: 0.92137 || Validation Loss: 0.27680 Validation Accuracy: 0.92240
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.27825 Train Accucracy: 0.92235 || Validation Loss: 0.27451 Validation Accuracy: 0.92230
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.27326 Train Accucracy: 0.92388 || Validation Loss: 0.26967 Validation Accuracy: 0.92420
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.26981 Train Accucracy: 0.92505 || Validation Loss: 0.26800 Validation Accuracy: 0.92490
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.26707 Train Accucracy: 0.92630 || Validation Loss: 0.26735 Validation Accuracy: 0.92470
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.26327 Train Accucracy: 0.92690 || Validation Loss: 0.26478 Validation Accuracy: 0.92510
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.26065 Train Accucracy: 0.92788 || Validation Loss: 0.26395 Validation Accuracy: 0.92670
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.25836 Train Accucracy: 0.92838 || Validation Loss: 0.26292 Validation Accuracy: 0.92630
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.25609 Train Accucracy: 0.92873 || Validation Loss: 0.26118 Validation Accuracy: 0.92560
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.25531 Train Accucracy: 0.92898 || Validation Loss: 0.26132 Validation Accuracy: 0.92750
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.25433 Train Accucracy: 0.92980 || Validation Loss: 0.25927 Validation Accuracy: 0.92700
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.25269 Train Accucracy: 0.92967 || Validation Loss: 0.26031 Validation Accuracy: 0.92610
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.25085 Train Accucracy: 0.93072 || Validation Loss: 0.25976 Validation Accuracy: 0.92740
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.24922 Train Accucracy: 0.93195 || Validation Loss: 0.25925 Validation Accuracy: 0.92770
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.24793 Train Accucracy: 0.93190 || Validation Loss: 0.25885 Validation Accuracy: 0.92690
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.24731 Train Accucracy: 0.93237 || Validation Loss: 0.25981 Validation Accuracy: 0.92670
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.24598 Train Accucracy: 0.93232 || Validation Loss: 0.25759 Validation Accuracy: 0.92860
# ====================================================================================================
# Epoch[24/100] - Train loss: 0.24722 Train Accucracy: 0.93225 || Validation Loss: 0.26108 Validation Accuracy: 0.92620
# ====================================================================================================
# Epoch[25/100] - Train loss: 0.24406 Train Accucracy: 0.93278 || Validation Loss: 0.25835 Validation Accuracy: 0.92840
# ====================================================================================================
# Epoch[26/100] - Train loss: 0.24460 Train Accucracy: 0.93240 || Validation Loss: 0.25827 Validation Accuracy: 0.92800
# ====================================================================================================
# Epoch[27/100] - Train loss: 0.24358 Train Accucracy: 0.93335 || Validation Loss: 0.26033 Validation Accuracy: 0.92680
# ====================================================================================================
# Epoch[28/100] - Train loss: 0.24226 Train Accucracy: 0.93343 || Validation Loss: 0.25858 Validation Accuracy: 0.92770
# ====================================================================================================
# Epoch[29/100] - Train loss: 0.24160 Train Accucracy: 0.93327 || Validation Loss: 0.25855 Validation Accuracy: 0.92760
# ====================================================================================================
# Epoch[30/100] - Train loss: 0.24046 Train Accucracy: 0.93397 || Validation Loss: 0.25764 Validation Accuracy: 0.92810
# ====================================================================================================
# Epoch[31/100] - Train loss: 0.24093 Train Accucracy: 0.93345 || Validation Loss: 0.26084 Validation Accuracy: 0.92650
# ====================================================================================================
# Epoch[32/100] - Train loss: 0.24061 Train Accucracy: 0.93362 || Validation Loss: 0.25923 Validation Accuracy: 0.92710
# ====================================================================================================
# Epoch[33/100] - Train loss: 0.23894 Train Accucracy: 0.93473 || Validation Loss: 0.25954 Validation Accuracy: 0.92680
# ====================================================================================================
# Early stopping: Epoch - 32
# 261.42576813697815 초

# %% [markdown]
# ## 큰모델

# %%
# ######  nn.Sequential() -> layer block: 레이어함수들을 묶어놓은 블록
s = nn.Sequential(
    nn.Linear(10, 20),
    nn.ReLU(),
    nn.Linear(20, 30),
    nn.ReLU() 
)
i = torch.randn(5, 10, dtype=torch.float32)
o = s(i)
print(o.shape)
o
# Out:
# torch.Size([5, 30])
# tensor([[ 0.0128, -0.1864,  0.0390, -0.7679,  0.6626,  0.1825,  0.1356, -0.0668,
#           0.6018, -0.8059,  0.0294, -0.4793,  0.3724,  0.3127,  0.2903, -0.3689,
#           0.8163,  1.0550, -0.7256, -0.2483,  0.3511, -0.7350,  0.0951, -0.1801,
#           0.6598, -0.3667,  0.2543,  0.5076, -0.3947, -0.7840],
#         [ 0.1179, -0.0228,  0.2141, -0.4208,  0.6767,  0.5856,  0.1126,  0.1481,
#           0.5707,  0.6006, -0.3934,  0.0230,  0.5674,  0.7930,  0.6456,  0.1415,
#           0.8958,  0.4446, -0.0722,  0.1673, -0.0694,  0.1049, -0.4748, -0.1166,
#           0.4775, -0.7397, -0.3095,  0.8523,  0.1573, -0.7709],
#         [ 0.3858,  0.9017, -0.2108,  0.1237,  0.9623,  0.4201, -0.6262, -0.0619,
#           0.1240,  0.4065, -0.7459,  0.0522,  0.3333, -0.1338,  0.6862,  0.3964,
#          -0.4203, -1.2639, -0.2297, -0.4603, -0.3086,  0.2416, -0.3897, -0.2960,
#          -0.4749, -0.2041, -0.2367,  0.5015, -0.3267,  0.4175],
#         [ 0.3419,  0.3806, -0.0543, -0.3487,  0.4138,  0.0489, -0.4714, -0.3278,
#           0.2010, -0.2046, -0.1457, -0.0728,  0.0846, -0.0514,  0.1336,  0.0062,
#           0.1194, -0.1943,  0.0776, -0.3416, -0.2977, -0.2884,  0.0815,  0.0958,
#          -0.1297, -0.1383, -0.0026,  0.0880, -0.4976, -0.2515],
#         [ 0.4425, -0.4311,  0.1778, -0.0486, -0.3624,  0.3934,  0.3820, -0.2087,
#           0.0652,  0.4516, -0.1722,  0.3270,  0.1307,  0.2623, -0.4094,  0.0163,
#           0.9533,  0.3040,  0.5652,  0.5986, -0.5386,  0.0244, -0.0156,  0.4197,
#           0.4791, -0.3126, -0.0431, -0.1019,  0.5193, -0.8818]],
#        grad_fn=<AddmmBackward0>)

# %%
class BigModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.ReLU())
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU())
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU())
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU())
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU())
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU())
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU())
        self.out_block = nn.Linear(32, 10)
        
    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
big_model = BigModel().to(device)
summary(big_model, (100, 1, 28, 28), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BigModel                                 [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-4                       [100, 1024]               2,098,176
# │    └─ReLU: 2-5                         [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-6                       [100, 512]                524,800
# │    └─ReLU: 2-7                         [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-8                       [100, 256]                131,328
# │    └─ReLU: 2-9                         [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-10                      [100, 128]                32,896
# │    └─ReLU: 2-11                        [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-12                      [100, 64]                 8,256
# │    └─ReLU: 2-13                        [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-14                      [100, 32]                 2,080
# │    └─ReLU: 2-15                        [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(big_model.parameters(), lr=lr)

# %%
train_loss_list2, train_acc_list2, valid_loss_list2, valid_acc_list2 = fit(
    train_loader, test_loader,
    small_model,
    loss_fn,
    optimizer,
    epochs,
    save_best_model=False,
    patience=5,
    device=device,
    mode="multi",
    lr_scheduler=lr_scheduler
)
# Out:
# >>>>>>Learning Rate가 0.001에서 0.0009755527298894294로 변경됨<<<<<<
# Epoch[1/100] - Train loss: 0.48673 Train Accucracy: 0.87910 || Validation Loss: 0.46283 Validation Accuracy: 0.88950
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009755527298894294에서 0.0009046039886902864로 변경됨<<<<<<
# Epoch[2/100] - Train loss: 0.38228 Train Accucracy: 0.89935 || Validation Loss: 0.36131 Validation Accuracy: 0.90540
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009046039886902864에서 0.0007940987335200904로 변경됨<<<<<<
# Epoch[3/100] - Train loss: 0.34410 Train Accucracy: 0.90735 || Validation Loss: 0.32788 Validation Accuracy: 0.91140
# ====================================================================================================
# >>>>>>Learning Rate가 0.0007940987335200904에서 0.0006548539886902864로 변경됨<<<<<<
# Epoch[4/100] - Train loss: 0.32293 Train Accucracy: 0.91258 || Validation Loss: 0.30896 Validation Accuracy: 0.91560
# ====================================================================================================
# >>>>>>Learning Rate가 0.0006548539886902864에서 0.0005005000000000001로 변경됨<<<<<<
# Epoch[5/100] - Train loss: 0.31176 Train Accucracy: 0.91543 || Validation Loss: 0.30076 Validation Accuracy: 0.91650
# ====================================================================================================
# >>>>>>Learning Rate가 0.0005005000000000001에서 0.0003461460113097139로 변경됨<<<<<<
# Epoch[6/100] - Train loss: 0.30362 Train Accucracy: 0.91707 || Validation Loss: 0.29257 Validation Accuracy: 0.91830
# ====================================================================================================
# >>>>>>Learning Rate가 0.0003461460113097139에서 0.00020690126647990973로 변경됨<<<<<<
# Epoch[7/100] - Train loss: 0.29924 Train Accucracy: 0.91807 || Validation Loss: 0.28898 Validation Accuracy: 0.91840
# ====================================================================================================
# >>>>>>Learning Rate가 0.00020690126647990973에서 9.639601130971382e-05로 변경됨<<<<<<
# Epoch[8/100] - Train loss: 0.29687 Train Accucracy: 0.91848 || Validation Loss: 0.28655 Validation Accuracy: 0.91990
# ====================================================================================================
# >>>>>>Learning Rate가 9.639601130971382e-05에서 2.5447270110570814e-05로 변경됨<<<<<<
# Epoch[9/100] - Train loss: 0.29505 Train Accucracy: 0.91893 || Validation Loss: 0.28577 Validation Accuracy: 0.91950
# ====================================================================================================
# >>>>>>Learning Rate가 2.5447270110570814e-05에서 0.001로 변경됨<<<<<<
# Epoch[10/100] - Train loss: 0.29549 Train Accucracy: 0.91898 || Validation Loss: 0.28557 Validation Accuracy: 0.91940
# ====================================================================================================
# >>>>>>Learning Rate가 0.001에서 0.0009938503261272714로 변경됨<<<<<<
# Epoch[11/100] - Train loss: 0.28715 Train Accucracy: 0.92103 || Validation Loss: 0.28083 Validation Accuracy: 0.92070
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009938503261272714에서 0.0009755527298894294로 변경됨<<<<<<
# Epoch[12/100] - Train loss: 0.27975 Train Accucracy: 0.92257 || Validation Loss: 0.27459 Validation Accuracy: 0.92300
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009755527298894294에서 0.0009455577588320898로 변경됨<<<<<<
# Epoch[13/100] - Train loss: 0.27520 Train Accucracy: 0.92378 || Validation Loss: 0.27226 Validation Accuracy: 0.92380
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009455577588320898에서 0.0009046039886902864로 변경됨<<<<<<
# Epoch[14/100] - Train loss: 0.27017 Train Accucracy: 0.92472 || Validation Loss: 0.26862 Validation Accuracy: 0.92340
# ====================================================================================================
# >>>>>>Learning Rate가 0.0009046039886902864에서 0.0008536998372026805로 변경됨<<<<<<
# Epoch[15/100] - Train loss: 0.26625 Train Accucracy: 0.92560 || Validation Loss: 0.26689 Validation Accuracy: 0.92550
# ====================================================================================================
# >>>>>>Learning Rate가 0.0008536998372026805에서 0.0007940987335200904로 변경됨<<<<<<
# Epoch[16/100] - Train loss: 0.26415 Train Accucracy: 0.92595 || Validation Loss: 0.26521 Validation Accuracy: 0.92450
# ====================================================================================================
# >>>>>>Learning Rate가 0.0007940987335200904에서 0.0007272682546199037로 변경됨<<<<<<
# Epoch[17/100] - Train loss: 0.26175 Train Accucracy: 0.92642 || Validation Loss: 0.26280 Validation Accuracy: 0.92560
# ====================================================================================================
# >>>>>>Learning Rate가 0.0007272682546199037에서 0.0006548539886902864로 변경됨<<<<<<
# Epoch[18/100] - Train loss: 0.26058 Train Accucracy: 0.92735 || Validation Loss: 0.26410 Validation Accuracy: 0.92430
# ====================================================================================================
# >>>>>>Learning Rate가 0.0006548539886902864에서 0.0005786390152875954로 변경됨<<<<<<
# Epoch[19/100] - Train loss: 0.25836 Train Accucracy: 0.92810 || Validation Loss: 0.26309 Validation Accuracy: 0.92520
# ====================================================================================================
# >>>>>>Learning Rate가 0.0005786390152875954에서 0.0005005000000000001로 변경됨<<<<<<
# Epoch[20/100] - Train loss: 0.25734 Train Accucracy: 0.92838 || Validation Loss: 0.26173 Validation Accuracy: 0.92660
# ====================================================================================================
# >>>>>>Learning Rate가 0.0005005000000000001에서 0.00042236098471240487로 변경됨<<<<<<
# Epoch[21/100] - Train loss: 0.25633 Train Accucracy: 0.92880 || Validation Loss: 0.26088 Validation Accuracy: 0.92630
# ====================================================================================================
# >>>>>>Learning Rate가 0.00042236098471240487에서 0.0003461460113097139로 변경됨<<<<<<
# Epoch[22/100] - Train loss: 0.25509 Train Accucracy: 0.92882 || Validation Loss: 0.26105 Validation Accuracy: 0.92600
# ====================================================================================================
# >>>>>>Learning Rate가 0.0003461460113097139에서 0.00027373174538009644로 변경됨<<<<<<
# Epoch[23/100] - Train loss: 0.25485 Train Accucracy: 0.92892 || Validation Loss: 0.26041 Validation Accuracy: 0.92720
# ====================================================================================================
# >>>>>>Learning Rate가 0.00027373174538009644에서 0.00020690126647990973로 변경됨<<<<<<
# Epoch[24/100] - Train loss: 0.25398 Train Accucracy: 0.92972 || Validation Loss: 0.26060 Validation Accuracy: 0.92670
# ====================================================================================================
# >>>>>>Learning Rate가 0.00020690126647990973에서 0.00014730016279731955로 변경됨<<<<<<
# Epoch[25/100] - Train loss: 0.25389 Train Accucracy: 0.92920 || Validation Loss: 0.25958 Validation Accuracy: 0.92610
# ====================================================================================================
# >>>>>>Learning Rate가 0.00014730016279731955에서 9.639601130971382e-05로 변경됨<<<<<<
# Epoch[26/100] - Train loss: 0.25331 Train Accucracy: 0.92923 || Validation Loss: 0.25981 Validation Accuracy: 0.92670
# ====================================================================================================
# >>>>>>Learning Rate가 9.639601130971382e-05에서 5.544224116791029e-05로 변경됨<<<<<<
# Epoch[27/100] - Train loss: 0.25319 Train Accucracy: 0.92930 || Validation Loss: 0.25980 Validation Accuracy: 0.92660
# ====================================================================================================
# >>>>>>Learning Rate가 5.544224116791029e-05에서 2.5447270110570814e-05로 변경됨<<<<<<
# Epoch[28/100] - Train loss: 0.25309 Train Accucracy: 0.92960 || Validation Loss: 0.25965 Validation Accuracy: 0.92670
# ====================================================================================================
# >>>>>>Learning Rate가 2.5447270110570814e-05에서 7.149673872728739e-06로 변경됨<<<<<<
# Epoch[29/100] - Train loss: 0.25294 Train Accucracy: 0.92943 || Validation Loss: 0.25970 Validation Accuracy: 0.92660
# ====================================================================================================
# >>>>>>Learning Rate가 7.149673872728739e-06에서 0.001로 변경됨<<<<<<
# Epoch[30/100] - Train loss: 0.25294 Train Accucracy: 0.92947 || Validation Loss: 0.25970 Validation Accuracy: 0.92660
# ====================================================================================================
# Early stopping: Epoch - 29
# 331.5017113685608 초

# %%
plot_fit_result(
    train_loss_list2, train_acc_list2, valid_loss_list2, valid_acc_list2
)

# %% [markdown]
# # Dropout 예제
#
# -   dropout 각 레이어에 적용
#     -   dropout은 nn.Dropout 객체를 사용
#     -   객체 생성시 dropout_rate 설정: 0.2 ~ 0.5
#     -   <font color='red'>Drop시킬 노드를 가진 Layer 뒤에 추가한다.</font>

# %%
class DropoutModel(nn.Module):

    def __init__(self, drop_rate=0.2):  # 20% 정도를 Dropout(0으로 바꿈)
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.out_block = nn.Linear(32, 10)
        
    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
dout_model = DropoutModel(drop_rate=0.5).to(device)
summary(dout_model, (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DropoutModel                             [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# │    └─Dropout: 2-4                      [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-5                       [100, 1024]               2,098,176
# │    └─ReLU: 2-6                         [100, 1024]               --
# │    └─Dropout: 2-7                      [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-8                       [100, 512]                524,800
# │    └─ReLU: 2-9                         [100, 512]                --
# │    └─Dropout: 2-10                     [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-11                      [100, 256]                131,328
# │    └─ReLU: 2-12                        [100, 256]                --
# │    └─Dropout: 2-13                     [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-14                      [100, 128]                32,896
# │    └─ReLU: 2-15                        [100, 128]                --
# │    └─Dropout: 2-16                     [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-17                      [100, 64]                 8,256
# │    └─ReLU: 2-18                        [100, 64]                 --
# │    └─Dropout: 2-19                     [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-20                      [100, 32]                 2,080
# │    └─ReLU: 2-21                        [100, 32]                 --
# │    └─Dropout: 2-22                     [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(dout_model.parameters(), lr=lr)

# %%
train_loss_list3, train_acc_list3, valid_loss_list3, valid_acc_list3 = fit(
    train_loader, test_loader,
    dout_model,
    loss_fn,
    optimizer,
    epochs,
    save_best_model=False,
    patience=5,
    device=device,
    mode="multi"
)
# Out:
# Epoch[1/100] - Train loss: 0.86285 Train Accucracy: 0.50523 || Validation Loss: 0.87210 Validation Accuracy: 0.50220
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.58255 Train Accucracy: 0.79342 || Validation Loss: 0.62647 Validation Accuracy: 0.78500
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.45511 Train Accucracy: 0.90323 || Validation Loss: 0.54814 Validation Accuracy: 0.90080
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.37337 Train Accucracy: 0.93662 || Validation Loss: 0.45892 Validation Accuracy: 0.93140
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.27873 Train Accucracy: 0.94847 || Validation Loss: 0.36199 Validation Accuracy: 0.94310
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.18420 Train Accucracy: 0.96268 || Validation Loss: 0.33472 Validation Accuracy: 0.95780
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.16753 Train Accucracy: 0.95978 || Validation Loss: 0.28819 Validation Accuracy: 0.95390
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.13540 Train Accucracy: 0.96790 || Validation Loss: 0.26792 Validation Accuracy: 0.96250
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.12232 Train Accucracy: 0.97158 || Validation Loss: 0.23572 Validation Accuracy: 0.96510
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.10543 Train Accucracy: 0.97547 || Validation Loss: 0.23464 Validation Accuracy: 0.96940
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.10601 Train Accucracy: 0.97550 || Validation Loss: 0.22216 Validation Accuracy: 0.96840
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.10243 Train Accucracy: 0.97528 || Validation Loss: 0.26262 Validation Accuracy: 0.96770
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.08890 Train Accucracy: 0.97875 || Validation Loss: 0.23386 Validation Accuracy: 0.97260
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.09738 Train Accucracy: 0.97523 || Validation Loss: 0.14867 Validation Accuracy: 0.96880
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.08808 Train Accucracy: 0.98098 || Validation Loss: 0.24870 Validation Accuracy: 0.97270
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.08733 Train Accucracy: 0.98017 || Validation Loss: 0.21873 Validation Accuracy: 0.97220
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.07432 Train Accucracy: 0.98103 || Validation Loss: 0.17657 Validation Accuracy: 0.97050
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.05965 Train Accucracy: 0.98505 || Validation Loss: 0.24732 Validation Accuracy: 0.97600
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.09001 Train Accucracy: 0.98040 || Validation Loss: 0.21096 Validation Accuracy: 0.96810
# ====================================================================================================
# Early stopping: Epoch - 18
# 888.2364196777344 초

# %%
plot_fit_result(train_loss_list3, train_acc_list3, valid_loss_list3, valid_acc_list3)

# %% [markdown]
# # Batch Normalization
#
# - Dense 와 Activation 사이에 정의한다.

# %%
# nn.BatchNorm1d(입력 feature개수)
# Linear -> BatchNorm -> ReLU(Activation)
# Linear -> BatchNorm -> ReLU(Activation) -> Dropout

class BatchNormModel(nn.Module):

    def __init__(self, drop_rate=0.2):
        super().__init__()
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(28*28, 2048), nn.BatchNorm1d(2048) ,nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.BatchNorm1d(1024), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.BatchNorm1d(512), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.BatchNorm1d(256), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.BatchNorm1d(128), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.BatchNorm1d(64), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.BatchNorm1d(32), nn.ReLU(), nn.Dropout(p=drop_rate))
        self.out_block = nn.Linear(32, 10)
        
    def forward(self, X):
        X = self.b1(X)
        X = self.b2(X)
        X = self.b3(X)
        X = self.b4(X)
        X = self.b5(X)
        X = self.b6(X)
        X = self.b7(X)
        return self.out_block(X)

# %%
bn_model = BatchNormModel(drop_rate=0.5).to(device)
summary(bn_model, (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BatchNormModel                           [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─BatchNorm1d: 2-3                  [100, 2048]               4,096
# │    └─ReLU: 2-4                         [100, 2048]               --
# │    └─Dropout: 2-5                      [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-6                       [100, 1024]               2,098,176
# │    └─BatchNorm1d: 2-7                  [100, 1024]               2,048
# │    └─ReLU: 2-8                         [100, 1024]               --
# │    └─Dropout: 2-9                      [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-10                      [100, 512]                524,800
# │    └─BatchNorm1d: 2-11                 [100, 512]                1,024
# │    └─ReLU: 2-12                        [100, 512]                --
# │    └─Dropout: 2-13                     [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-14                      [100, 256]                131,328
# │    └─BatchNorm1d: 2-15                 [100, 256]                512
# │    └─ReLU: 2-16                        [100, 256]                --
# │    └─Dropout: 2-17                     [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-18                      [100, 128]                32,896
# │    └─BatchNorm1d: 2-19                 [100, 128]                256
# │    └─ReLU: 2-20                        [100, 128]                --
# │    └─Dropout: 2-21                     [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-22                      [100, 64]                 8,256
# │    └─BatchNorm1d: 2-23                 [100, 64]                 128
# │    └─ReLU: 2-24                        [100, 64]                 --
# │    └─Dropout: 2-25                     [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-26                      [100, 32]                 2,080
# │    └─BatchNorm1d: 2-27                 [100, 32]                 64
# │    └─ReLU: 2-28                        [100, 32]                 --
# │    └─Dropout: 2-29                     [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,413,674
# Trainable params: 4,413,674
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 441.37
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 6.51
# Params size (MB): 17.65
# Estimated Total Size (MB): 24.48
# ==========================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(bn_model.parameters(), lr=lr)

train_loss_list3, train_acc_list3, valid_loss_list3, valid_acc_list3 = fit(
    train_loader, test_loader,
    bn_model,
    loss_fn,
    optimizer,
    epochs,
    save_best_model=False,
    patience=5,
    device=device,
    mode="multi"
)
# Out:
# Epoch[1/100] - Train loss: 0.36516 Train Accucracy: 0.94222 || Validation Loss: 0.36285 Validation Accuracy: 0.94170
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.17303 Train Accucracy: 0.95898 || Validation Loss: 0.17340 Validation Accuracy: 0.95670
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.11959 Train Accucracy: 0.97100 || Validation Loss: 0.13949 Validation Accuracy: 0.96540
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.10815 Train Accucracy: 0.97478 || Validation Loss: 0.11808 Validation Accuracy: 0.97060
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.09968 Train Accucracy: 0.97567 || Validation Loss: 0.12398 Validation Accuracy: 0.97000
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.08100 Train Accucracy: 0.98117 || Validation Loss: 0.10019 Validation Accuracy: 0.97610
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.07209 Train Accucracy: 0.98362 || Validation Loss: 0.10030 Validation Accuracy: 0.97600
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.06649 Train Accucracy: 0.98433 || Validation Loss: 0.10153 Validation Accuracy: 0.97570
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.06035 Train Accucracy: 0.98587 || Validation Loss: 0.09747 Validation Accuracy: 0.97630
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.05720 Train Accucracy: 0.98657 || Validation Loss: 0.08846 Validation Accuracy: 0.98040
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.04921 Train Accucracy: 0.98843 || Validation Loss: 0.08818 Validation Accuracy: 0.98030
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.04366 Train Accucracy: 0.98983 || Validation Loss: 0.08467 Validation Accuracy: 0.98120
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.03980 Train Accucracy: 0.99067 || Validation Loss: 0.09321 Validation Accuracy: 0.98020
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.04494 Train Accucracy: 0.98958 || Validation Loss: 0.08860 Validation Accuracy: 0.98090
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.03717 Train Accucracy: 0.99180 || Validation Loss: 0.08614 Validation Accuracy: 0.98270
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.03325 Train Accucracy: 0.99263 || Validation Loss: 0.08155 Validation Accuracy: 0.98220
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.04155 Train Accucracy: 0.99087 || Validation Loss: 0.09188 Validation Accuracy: 0.98120
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.03021 Train Accucracy: 0.99317 || Validation Loss: 0.07977 Validation Accuracy: 0.98310
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.02952 Train Accucracy: 0.99355 || Validation Loss: 0.08215 Validation Accuracy: 0.98390
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.02869 Train Accucracy: 0.99320 || Validation Loss: 0.08280 Validation Accuracy: 0.98320
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.02896 Train Accucracy: 0.99383 || Validation Loss: 0.08667 Validation Accuracy: 0.98450
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.02585 Train Accucracy: 0.99417 || Validation Loss: 0.08567 Validation Accuracy: 0.98330
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.02827 Train Accucracy: 0.99373 || Validation Loss: 0.08866 Validation Accuracy: 0.98230
# ====================================================================================================
# Early stopping: Epoch - 22
# 575.0832612514496 초

# %% [markdown]
# # Learning rate decay

# %% [markdown]
# ### Optimizer와 Learning rate scheduler의 속성, 메소드 확인
#
# -   파이토치는 `torch.optim` 모듈에서 다양한 Learning rate 알고리즘을 제공한다.

# %%
import matplotlib.pyplot as plt

def plot_lr(title, lr_list):
    """LearningRate 스케쥴러(학습도중 LR를 변경시키는 객체.)에 의해 변화되는 Learning Rate값을 시각화.

    Args:
        title (str): title
        lr_list (list): Learning Rate 스케쥴러에 의해 변경된 learning rate값들을 가지는 list
    """
    plt.figure(figsize=(15, 6))
    plt.plot(range(len(lr_list)), lr_list)

    plt.title(title)
    xticks = [x for x in range(len(lr_list)) if x % 10 == 0]
    plt.xticks(xticks)
    plt.xlabel("Epoch 수 또는 Step 수")
    plt.ylabel("학습률-LR")
    plt.grid(True, linestyle=":")
    plt.show()

# %% [markdown]
# #### StepLR

# %%
small_model = BatchNormModel() # 위 아무거나 써도 된다.
optim = torch.optim.Adam(small_model.parameters(), lr=0.001)

# optimizer에서 현재 LR을 조회
optim.param_groups[0]["lr"]
# Out:
# 0.001

# %%
# LearingRate Scheduler - StepLR - 계단 형태로 Learning Rate를 특정 step마다 특정 비율로 줄여나간다.
steplr_scheduler = torch.optim.lr_scheduler.StepLR(
    optim,        # 학습률을 변경할 옵티마이저.
    step_size=30, # 몇 step/epoch마다 Learning를 변경할지 -> lr_scheduler.step()을 30번 호출하면 변경.
    gamma=0.5,    # 변경할 비율.  새 lr = 현재 lr * gamma
)
# 30 step/epoch 마다 LR를 `현재학습률 * gamma` 로 변경.

# 현재 learning rate를 스케쥴러로 부터 조회
steplr_scheduler.get_last_lr()
# Out:
# [0.001]

# %%
steplr_scheduler.step()         # 30 번 실행시키면 값이 비율로 바뀜
steplr_scheduler.get_last_lr()

# %%
epochs = 300
step_size = 10 # len(dataloader)
lr_list = []
for epoch in range(epochs):
    
    for step in range(step_size): # for x, y in dataloader:
        # 1 step 학습
        # 1. x, y device로 이동
        # 2. 추론. p = model(x)
        # 3. loss. loss = loss_fn(p, y)
        # 4. grad. loss.backward()
        # 5. 파라미터 update
        optim.step()  
        # 6. grad 초기화
        optim.zero_grad() 
        
        # steplr_scheduler.step() # LR를 변경 요청. 1스텝이 끝나면 요청
        # lr_list.append(steplr_scheduler.get_last_lr()) # step()후 lr를 list에 저장.

    steplr_scheduler.step() # LR를 변경 요청. # 1에폭 끝나면 요청
    lr_list.append(steplr_scheduler.get_last_lr()) # step()후 lr를 list에 저장.

# %%
plt.rcParams['font.family'] = "malgun gothic"
plot_lr("Step LR", lr_list)

# %%
# 학습이 오래될 수록 LeaningRate가 0에 수렴한다

# %% [markdown]
# #### CosineAnnealingLR
#
# cosine 그래프를 그리면서 learning rate를 변경 하는 방식.
# 최근에는 learning rate를 단순히 감소시키기 보다는 감소와 증가를 반복하여 진동하는 방식으로 최적점을 찾아가는 알고리즘을 많이 사용한다. 이러한 방법 중 가장 간단하면서도 많이 사용되는 방법이 CosineAnnealingLR이다.

# %%
optim = torch.optim.Adam(small_model.parameters(), lr=0.001)
ca_lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optim,
    T_max=10, # 변화주기 step/epoch - 최대(초기LR) ~ 최소(eta_min), 최소 ~ 최대
    eta_min=1e-6, # lr 최소값 지정. 
)

# %%
lr_list = []
for epoch in range(epochs):
    for step in range(step_size):
        # ... 학습
        optim.step()
        optim.zero_grad()
    
    ca_lr_scheduler.step() # epoch단위로 lr 변경
    lr_list.append(ca_lr_scheduler.get_last_lr())

# %%
plot_lr("CosineAnnelingLR", lr_list)

# %% [markdown]
# #### CosineAnnealingWarmRestarts
#
# cosine annealing의 스케쥴링에 cosine 주기의 에폭을 점점 늘리거나 줄일 수 있다. (보통 늘린다.)

# %%
optim = torch.optim.Adam(small_model.parameters(), lr=0.001)
cawr_lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optim,
    T_0=10,   # 변화주기 (step/epoch) 최소(eta_min) <-> 최대(초기 lr)
    T_mult=2, # 새로운 변화주기(T_0) = 현재 T_O * T_mult (한 주기가 끝날때마다 T_O를 다시 계산.)
    eta_min=1e-6 # 0.000001
)

# %%
lr_list = []
for epoch in range(epochs):

    for step in range(step_size):
        # 학습
        optim.step()
        optim.zero_grad()

    cawr_lr_scheduler.step()
    lr_list.append(cawr_lr_scheduler.get_last_lr())

# %%
plot_lr("CosineAnnealingWarmRestart", lr_list)
