# %%
# 가상환경

# %% [markdown]
# <!-- # Langchain은 다양한 LLM(대규모 언어 모델)을 지원한다
# -	대규모 언어 모델(LLM, Large Language Model)을 개발하는 회사들은 사용자가 자신의 애플리케이션에서 LLM을 손쉽게 활용할 수 있도록 API(Application Programming Interface) 서비스를 제공하고 있다.
# -	하지만 각 LLM은 고유한 API 호출 라이브러리(Library)를 제공하기 때문에, 개발자는 동일한 작업을 수행하더라도 LLM에 따라 다른 코드를 작성해야 하는 번거로움이 있다.
# -	Langchain은 이러한 문제를 해결하기 위해 다양한 LLM의 API를 통합적으로 지원한다.
# -	여러 LLM을 동일한 인터페이스(interface)로 호출할 수 있게 하여 특정 모델에 종속되지 않도록 하고, 필요에 따라 쉽게 다른 모델로 전환할 수 있다.
# -	Langchain이 지원하는 주요 LLM 목록
#     - https://python.langchain.com/docs/integrations/chat/#featured-providers -->

# %% [markdown]
# # Model I/O
#
# - **Model I/O는 언어 모델(LLM)에 입력을 전달하고, 생성된 출력을 처리하는 과정과 이를 구성하는 요소들을 의미한다.**
# - LangChain에서는 주로 **프롬프트 템플릿**(**Prompt Template**), **언어 모델**(**Language Model**), **출력 파서**(**Output Parser**)를 사용하여 Model I/O를 구성한다.
#
# ## Model I/O 구성 요소
#
# ### 프롬프트 템플릿 (Prompt Template)
#
# - LLM에 전달할 프롬프트를 생성하는 역할을 한다.
# - 사용자 입력과 고정된 템플릿을 결합하여 일관된 형식의 프롬프트를 생성한다.
# - 프롬프트를 구조화하여 모델이 원하는 방식으로 응답하도록 유도한다.
#
# ### 대형 언어 모델 (LLM - Large Language Model)
#
# - 입력된 프롬프트를 기반으로 텍스트를 생성하거나 입력 내용을 분석하여 결과를 생성한다.
# - OpenAI의 GPT, Anthropic의 Claude, Google의 Gemini 등이 대표적인 언어 모델이다.
# - Langchain은 LLM 연동 API를 제공한다.
#
# ### 출력 파서 (Output Parser)
#
# - 언어 모델의 출력을 원하는 형식으로 변환하는 역할을 한다.
# - 텍스트 응답에서 필요한 정보를 추출하거나 JSON, Pydantic 객체 등 구조화된 데이터로 변환할 수 있다.
# - 출력 데이터를 정제하고 후처리하여 다음 단계에서 활용하기 쉽도록 만든다.
#
# ![model id](figures/model_io.jpg)

# %% [markdown]
# # Chatbot 서비스 사용과 LLM API 사용의 차이
#
# ChatGPT나 Claude 챗봇 서비스를 사용하는 것과 GPT 5.5 모델 또는 Opus 4.8 와 같은 LLM 모델을 API를 이용해 사용하는 것의 차이는 다음과 같이 정리할 수 있다.
#
# | 구분        | Chatbot서비스 사용       | LLM API 사용 |
# | --------- | ---------------- | ------------- |
# | 대상        | 일반 사용자           | 개발자           |
# | 목적        | AI를 바로 사용        | AI를 서비스에 내장   |
# | 인터페이스     | 웹/앱              | 프로그래밍 코드      |
# | 사용자 제어 수준     | 제한적       | 매우 높음         |
# | 비용        | 구독료(Plus, Pro 등) | 사용량 기반 과금     |
# | 개발 가능성    | 없음               | 가능            |
# | 시스템 프롬프트  | 일부만 가능           | 완전 제어         |
# | 외부 시스템 연동 | 제한적              | 자유롭게 가능       |
#
# **ChatGPT와 같은 LLM 기반 Chatbot는 완성된 AI 서비스**이고, **OpenAI GPT 5.5 같은 API는 단순히 응답을 생성해 주는 LLM 모델을 이용해 AI 서비스를 만들기 위한 것**이다.

# %% [markdown]
# # OpenAI 모델 사용
# - https://platform.openai.com
#
# ## 결제
# 1. 로그인 후 Billing 페이지로 이동.
#    - **신용카드가 등록된 경우 바로 충전할 수 있다.**
#    - setting -> Billing
#
#    ![openai_payment.png](figures/openai_payment.png)
#    - 금액 입력 후 `continue`
#    - 다음 페이지에서 세금 포함 결제 금액 나오면 `Confirm`  한다.
#
# 2. 신용카드 등록
#    - Payment methods 탭을 선택하고 카드를 등록한다.
#
#    ![openai_payment2.png](figures/openai_payment2.png)
#
#    - 등록이 끝나면 최초 구매를 진행한다. $5 ~ $100 사이의 금액을 선택할 수 있다.
#    - 자동 충전을 설정하고 싶다면 automatic recharge 를 활성화 하고 아래 추가 설정에 입력한다.
#      - 자동 충전은 특정 금액 이하로 떨어지면 자동으로 충전한다. (**비활성화**)
#
#    ![openai_payment3.png](figures/openai_payment3.png)
#
# 3. 수동으로 **추가 결제하기**
#    - Billing 페이지의 Overview에서 `Add to credit balance` 를 클릭한 뒤 금액을 입력하고 결제한다.
#
# ## 사용량 확인
# - profile/설정 -> Usage 에서 확인

# %% [markdown]
# ## API Key 생성
#
# ![openai_create_apikey.png](figures/openai_create_apikey.png)
#
# - 로그인 -> Dashboard -> API Keys -> Create New Secreat Key
# > Settings -> API Keys
#
# ## API Key 등록
# - 환경변수에 등록
#   - 변수이름: OPENAI_API_KEY
#   - 값: 생성된 키
# - dotenv를 이용해서 load
#   - Working directory에  `.env` 파일 생성하고 `OPENAI_API_KEY=생성된키` 추가한다.
#   - load_dotenv() 호출 하면 .env 파일에 있는 값을 읽은 뒤 환경변수로 등록한다.
# - **주의**
#   - 생성된 API Key는 노출되면 안된다.
#   - API Key가 저장된 파일(코드나 설정파일)이 github에 올라가 공개되서는 안된다.
#
# ## 사용 비용 확인
# - settings -> Usage 에서 확인
#
# ## OpenAI LLM 모델들
# -  OpenAI LLM 모델: https://platform.openai.com/docs/models
# -  모델별 가격: https://platform.openai.com/docs/pricing
# -  토큰사이즈 확인: https://platform.openai.com/tokenizer
#    -  1토큰: 영어 3\~4글자 정도, 한글: 대략 1\~2글자 정도
#    -  모델이 업데이트 되면서 토큰 사이즈도 조금씩 커지고 있다.

# %% [markdown]
# ## OpenAI 를 연동하기 위한 package 설치
# ```bash
# pip install langchain-openai -qU
# ```
#
# - OpenAI 자체 라이브러리 설치
#     - `pip install openai -qU`
#     - langchain-openai를 설치하면 같이 설치 된다.

# %% [markdown]
# ## OpenAI Library 를 이용한 API 호출

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()   # 환경변수로 등록안한 경우 API Key를 설정.
response = client.chat.completions.create(
    model="gpt-5.4-nano",
    messages=[
        {"role":"user", "content":"OpenAI의 LLM 모델 종류는 뭐가 있나요?"}
    ]   # 프로프트 입력 - 대화형식
)

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-DsLpqx454527X7H8pbVY2T2DWH8eu', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='OpenAI에서 제공(또는 제공해 온) **LLM(대규모 언어 모델)**의 대표적인 종류는 보통 “모델 계열(패밀리)”로 나눠 소개됩니다. 다만, 현재 시점에서 정확히 어떤 모델이 **API에서 사용 가능**한지/정식 명칭은 자주 바뀔 수 있어요. 아래는 널리 알려진 계열들을 기준으로 정리한 목록입니다.\n\n## 1) GPT 계열(범용 생성형)\n- **GPT-4 / GPT-4 계열(예: GPT-4, GPT-4 Turbo 등)**: 고성능 범용 대화/추론/코딩.\n- **GPT-3.5 계열(예: GPT-3.5 Turbo 등)**: 상대적으로 저비용·빠른 응답(과거에 많이 사용).\n- **GPT-4o(“omni”) 계열**: 텍스트 중심뿐 아니라 음성/비전 등 멀티모달로 확장된 계열(제품/기능에 따라 차이).\n\n## 2) o 계열(추론 특화)\n- **o 계열(예: o1, o1-mini, o3-mini 등)**: “추론을 더 잘 하도록” 설계된 모델 라인업으로 알려져 있습니다.  \n  (정확한 세부는 모델/업데이트에 따라 다를 수 있어요.)\n\n## 3) 이전/특정 목적 계열\n- **Codex 계열(코딩 특화)**: 예전에는 코딩/자동완성 용도로 많이 언급되었습니다.\n- (그 외) **특정 도메인/임베딩/기타 작업용 모델**도 있는데, 이것들은 “LLM(언어 생성)”이라기보다 **임베딩/분류** 목적일 때가 많습니다.\n\n---\n\n### 확인 질문 (원하시면 더 정확히 정리해드릴게요)\n“모델 종류”를 **(1) 개념적인 계열**로 알고 싶으신가요, 아니면 **(2) 지금 OpenAI API에서 실제로 사용 가능한 모델 목록**을 원하시나요?  \n원하시는 기준에 맞춰 최신 목록 형태로 정리해드릴 수 있어요.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1781846018, model='gpt-5.4-nano-2026-03-17', object='chat.completion', moderation=None, service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=497, prompt_tokens=19, total_tokens=516, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
print(response.choices[0].message.content)
# Out:
# OpenAI에서 제공(또는 제공해 온) **LLM(대규모 언어 모델)**의 대표적인 종류는 보통 “모델 계열(패밀리)”로 나눠 소개됩니다. 다만, 현재 시점에서 정확히 어떤 모델이 **API에서 사용 가능**한지/정식 명칭은 자주 바뀔 수 있어요. 아래는 널리 알려진 계열들을 기준으로 정리한 목록입니다.
#
# ## 1) GPT 계열(범용 생성형)
# - **GPT-4 / GPT-4 계열(예: GPT-4, GPT-4 Turbo 등)**: 고성능 범용 대화/추론/코딩.
# - **GPT-3.5 계열(예: GPT-3.5 Turbo 등)**: 상대적으로 저비용·빠른 응답(과거에 많이 사용).
# - **GPT-4o(“omni”) 계열**: 텍스트 중심뿐 아니라 음성/비전 등 멀티모달로 확장된 계열(제품/기능에 따라 차이).
#
# ## 2) o 계열(추론 특화)
# - **o 계열(예: o1, o1-mini, o3-mini 등)**: “추론을 더 잘 하도록” 설계된 모델 라인업으로 알려져 있습니다.
#   (정확한 세부는 모델/업데이트에 따라 다를 수 있어요.)
#
# ## 3) 이전/특정 목적 계열
# - **Codex 계열(코딩 특화)**: 예전에는 코딩/자동완성 용도로 많이 언급되었습니다.
# - (그 외) **특정 도메인/임베딩/기타 작업용 모델**도 있는데, 이것들은 “LLM(언어 생성)”이라기보다 **임베딩/분류** 목적일 때가 많습니다.
#
# ---
#
# ### 확인 질문 (원하시면 더 정확히 정리해드릴게요)
# “모델 종류”를 **(1) 개념적인 계열**로 알고 싶으신가요, 아니면 **(2) 지금 OpenAI API에서 실제로 사용 가능한 모델 목록**을 원하시나요?
# 원하시는 기준에 맞춰 최신 목록 형태로 정리해드릴 수 있어요.

# %% [markdown]
# ## Langchain을 이용한 OpenAI API 호출
#
# - **ChatOpenAI**
#     - chat (대화-채팅) 기반 모델 model.
#     - Default 로 gpt-3.5-turbo 사용
#     - llm 전달 입력과 llm 응답 출력 타입:  Message
# - **Initializer 주요 파라미터**
#     -  **model**
#         -  사용할 openai 모델 지정
#     -  **temperature**
#         -  llm 모델의 출력 무작위성을 지정한다.
#         -  0 ~ 2 사이 실수를 설정하며 클 수록 무작위성이 커진다. 기본값: 0.7
#         -  정확한 답변을 얻어야 하는 경우 작은 값을 창작을 해야 하는 경우 큰 값을 지정한다.
#            -  정확한 답변: 0.0 ~ 0.3
#            -  일반 챗봇: 0.5 ~ 0.8
#            -  창작: 1.0 이상
#     - **max_tokens**:
#         - llm 모델이 응답할 최대 token 수.
#         - gpt-5 모델은 추론과정을 거칠 수있고 이 경우 토큰을 소비한다. 그래서 max_tokens를 너무 작게 잡으면 응답이 안올 수있다.
#     - **api_key**
#         - OpenAI API key를 직접 입력해 생성시 사용.
#         - API key가 환경변수에 설정 되있으면 생략한다.
#     - **OpenAI GPT-5 계열 모델 파라미터**
#         - **reasoning_effort**
#             - 모델의 추론 강도
#             - None, "low", "medium", "high", "xlarge"
#         - **verbosity**
#             - 응답 길이 제어.
#             - "low", "medium", "high"
# -  메소드
#     - **`invoke(message)`** : LLM에 프롬프트 메세지를 전달하며 LLM의 응답을 반환한다.

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="gpt-5.4-nano",
    temperature=1.0,
)
response = model.invoke("OpenAI의 LLM 모델 종류는 뭐가 있나요?")

# %%
response
# Out:
# AIMessage(content='OpenAI에서 사용하는(또는 공개된) LLM 모델은 시기별로 구분되고, 보통 **“GPT 계열(텍스트/대화)”**, **“코딩 특화(또는 코딩 지원)”**, **“멀티모달(이미지/음성 등)”**로 나뉩니다. 대표적으로 아래 계열이 알려져 있어요.\n\n## 1) GPT(대화/일반 텍스트) 계열\n- **GPT-4 계열**(예: GPT-4, GPT-4 Turbo 등으로 알려짐)\n- **GPT-3.5 계열**(예: GPT-3.5 Turbo 등)\n\n## 2) 최신 GPT 계열(세대별)\n- **GPT-4o(“omni”) 계열**: 텍스트뿐 아니라 이미지 등 멀티모달을 지원하는 것으로 널리 알려져 있습니다.\n- **GPT-4.1** 같은 형태로 후속/개량 모델이 출시되기도 합니다(시점에 따라 목록이 바뀔 수 있어요).\n\n## 3) 코드/개발 지원 특화\n- **Codex 계열**(과거) 또는\n- **코딩에 최적화된 GPT 변형들**(현재는 GPT-4o/4.1 등에서 코딩 성능을 함께 제공하는 형태가 많습니다)\n\n## 4) 멀티모달(이미지/오디오 등) 모델\n- **GPT-4o 계열**처럼 텍스트+이미지(및 경우에 따라 음성) 처리를 지원하는 모델들이 있습니다.\n\n---\n\n### 중요한 점(정확성 관련)\nOpenAI 모델 “종류”는 **공개/운영 정책, 출시 시점, API에서 제공되는 모델명**에 따라 계속 바뀝니다. 그래서 질문하신 “현재 정확한 모델 목록”은 **OpenAI API 콘솔/문서에서 제공되는 모델 목록**을 확인하는 게 가장 확실해요.\n\n원하시면, **사용 목적(예: 대화, 문서요약, 코딩, 이미지 입력)** 과 **원하는 품질/비용(빠르게 vs 정확하게)** 을 알려주시면, 그 목적에 맞춰 어떤 모델 계열을 쓰는 게 일반적으로 좋은지 추천해드릴게요.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 503, 'prompt_tokens': 19, 'total_tokens': 522, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DsM93gb7pQxrhX1GqAQz8N9RlIK5L', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ede5e-af67-7572-8c31-0b6076a120c0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 503, 'total_tokens': 522, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(response.content)
# Out:
# OpenAI에서 사용하는(또는 공개된) LLM 모델은 시기별로 구분되고, 보통 **“GPT 계열(텍스트/대화)”**, **“코딩 특화(또는 코딩 지원)”**, **“멀티모달(이미지/음성 등)”**로 나뉩니다. 대표적으로 아래 계열이 알려져 있어요.
#
# ## 1) GPT(대화/일반 텍스트) 계열
# - **GPT-4 계열**(예: GPT-4, GPT-4 Turbo 등으로 알려짐)
# - **GPT-3.5 계열**(예: GPT-3.5 Turbo 등)
#
# ## 2) 최신 GPT 계열(세대별)
# - **GPT-4o(“omni”) 계열**: 텍스트뿐 아니라 이미지 등 멀티모달을 지원하는 것으로 널리 알려져 있습니다.
# - **GPT-4.1** 같은 형태로 후속/개량 모델이 출시되기도 합니다(시점에 따라 목록이 바뀔 수 있어요).
#
# ## 3) 코드/개발 지원 특화
# - **Codex 계열**(과거) 또는
# - **코딩에 최적화된 GPT 변형들**(현재는 GPT-4o/4.1 등에서 코딩 성능을 함께 제공하는 형태가 많습니다)
#
# ## 4) 멀티모달(이미지/오디오 등) 모델
# - **GPT-4o 계열**처럼 텍스트+이미지(및 경우에 따라 음성) 처리를 지원하는 모델들이 있습니다.
#
# ---
#
# ### 중요한 점(정확성 관련)
# OpenAI 모델 “종류”는 **공개/운영 정책, 출시 시점, API에서 제공되는 모델명**에 따라 계속 바뀝니다. 그래서 질문하신 “현재 정확한 모델 목록”은 **OpenAI API 콘솔/문서에서 제공되는 모델 목록**을 확인하는 게 가장 확실해요.
#
# 원하시면, **사용 목적(예: 대화, 문서요약, 코딩, 이미지 입력)** 과 **원하는 품질/비용(빠르게 vs 정확하게)** 을 알려주시면, 그 목적에 맞춰 어떤 모델 계열을 쓰는 게 일반적으로 좋은지 추천해드릴게요.

# %%
# streaming 방식으로 응답 받기.

response = model.stream("LangChain은 어떤 Framework인가요? 자세하게 설명해줘")
response
# Out:
# <generator object BaseChatModel.stream at 0x000001AFF3018800>

# %%
for token in response:
    print(token.content, end="")
# Out:
# LangChain은 **LLM(대규모 언어 모델)을 애플리케이션에 쉽게 연결·조합**할 수 있게 해주는 **오픈소스 프레임워크**입니다. 한마디로, “LLM을 중심으로 한 챗봇/에이전트/검색·요약·툴사용 같은 기능”을 만들 때 필요한 구성 요소(프롬프트, 체인, 검색, 툴 호출, 메모리 등)를 표준화해서 제공해 줍니다.
#
# 아래에서 핵심 개념부터 “왜 쓰는지”, “어떻게 구성되는지”를 좀 더 자세히 설명할게요.
#
# ---
#
# ## 1) LangChain이 하는 일: LLM 앱을 ‘조립’하기 쉽게
# LLM을 쓰면 보통 다음 작업이 반복됩니다.
#
# - 프롬프트 작성(시스템/유저 메시지, 템플릿)
# - 사용자 질문을 바탕으로 문서 검색(RAG)
# - 검색 결과를 프롬프트에 끼워 넣기
# - 도구(예: 웹검색, DB 조회, 계산기)를 호출
# - 대화 맥락을 기억(메모리)
# - 여러 단계를 순서대로 실행(요약 → 추출 → 검증 등)
# - 결과를 특정 포맷(JSON 등)으로 구조화
#
# LangChain은 이런 작업들을 **체인(Chain)**, **에이전트(Agent)**, **리트리버(Retriever)**, **메모리(Memory)** 같은 구성요소로 만들어서, 개발자가 “부품을 이어 붙이듯” 구현할 수 있게 해줍니다.
#
# ---
#
# ## 2) 주요 구성 요소(개념)들
#
# ### (1) Models(모델 래퍼)
# OpenAI, Anthropic, Google, 로컬 모델 등 다양한 LLM을 동일한 방식으로 호출하도록 추상화합니다.
# 즉, 모델 제공자가 바뀌어도 코드 구조를 덜 깨고 전환할 수 있습니다.
#
# ### (2) Prompt Templates(프롬프트 템플릿)
# 프롬프트를 코드에서 **재사용/관리**하기 쉽게 템플릿화합니다.
#
# - 예: `{question}`, `{context}` 같은 변수를 받아서 완성 프롬프트 생성
# - 시스템 메시지 + 사용자 메시지 구성 관리
# - 출력 형식(JSON, 표 등) 지시 포함
#
# ### (3) Chains(체인)
# **여러 단계 작업을 순차적으로 연결**한 흐름입니다.
#
# 예)
# 1. 질문 분류(의도 파악)
# 2. 해당 의도에 맞는 검색 쿼리 생성
# 3. 문서 검색
# 4. 검색 결과 요약
# 5. 최종 답변 생성
#
# 이런 파이프라인을 LangChain은 “체인”으로 정리해 줍니다.
#
# ### (4) RAG(검색증강: Retrieval Augmented Generation)
# LangChain은 RAG를 만들기 위한 구성요소가 많습니다.
#
# - 문서 로드/분할(Chunking)
# - 임베딩 생성
# - 벡터스토어에 저장(예: FAISS, Chroma, Pinecone 등)
# - 검색(유사도/키워드)
# - 검색 결과를 프롬프트에 넣어 답변 생성
#
# RAG는 “모델이 아는 지식”에만 의존하지 않고, **외부 문서 지식**을 답변에 반영하게 해줍니다.
#
# ### (5) Agents(에이전트)
# 에이전트는 LLM이 단순히 답만 하는 게 아니라,
# 필요할 때 **도구를 선택하고 호출**하도록 설계된 방식입니다.
#
# 예)
# - 질문에 따라 웹검색 도구 사용
# - DB 조회 도구 호출
# - 계산기/함수 호출
# - 그 결과를 바탕으로 답변 작성
#
# 즉 “툴 사용(Tool use)”을 포함한 상호작용형 흐름을 구성합니다.
#
# ### (6) Memory(메모리)
# 대화의 과거 내용이나 상태를 유지해서, 길게 이어지는 대화에서 문맥을 반영합니다.
#
# - 단순 최근 대화만 기억
# - 요약해서 기억(길이 제한 대응)
# - 세션별 상태 유지
#
# ### (7) Output Parsing(출력 파싱/구조화)
# LLM의 텍스트 출력이 아니라,
# JSON 형태 등 **구조화된 결과**로 받도록 처리할 수 있습니다.
#
# - “이 포맷으로만 출력해줘” 프롬프트 + 파싱 로직
# - 유효성 검사 및 재시도 전략과 함께 사용
#
# ---
#
# ## 3) LangChain을 쓰는 이유(장점)
#
# 1. **구현 속도 향상**
#    - 프롬프트/체인/RAG/도구호출 등 반복되는 부분을 재사용 가능한 형태로 제공합니다.
#
# 2. **유연한 조합**
#    - “검색 + 요약 + 검증 + 특정 포맷 출력”처럼 복잡한 작업을 모듈로 조합하기 쉽습니다.
#
# 3. **에코시스템**
#    - 많은 벡터스토어/모델/도구/문서 로더/유틸과 연결 포인트가 많습니다.
#
# 4. **LLM 기반 애플리케이션 패턴을 표준화**
#    - 흔한 RAG, 툴 사용, 체인 방식이 “검증된 패턴”으로 제공됩니다.
#
# ---
#
# ## 4) 언제 LangChain이 특히 유용한가?
#
# - **RAG**(사내 문서/매뉴얼/DB 기반 질의응답) 만들 때
# - 질문에 따라 **다른 도구를 호출**해야 할 때(에이전트)
# - 단계를 나눠 처리해야 할 때(예: 분류 → 검색 → 근거 인용 → 검증)
# - LLM 출력 형태를 **구조적으로** 받아야 하는 업무 자동화(티켓 분류, 정보 추출 등)
# - 멀티 모델/멀티 공급자 전환 가능성을 염두에 둘 때(추상화 활용)
#
# ---
#
# ## 5) 주의할 점(단점/개발 시 고려사항)
#
# - LangChain은 “도구”이지만, **성능/비용/정확도**는 설계에 크게 좌우됩니다.
#   - 예: 청킹 전략, 검색 품질, 프롬프트 설계, 재시도 정책 등이 중요
# - 복잡도가 커질수록 체인이 많아지고 **디버깅이 어려워질 수** 있습니다.
# - “정답 보장”보다는 **확률적 생성**이므로, 검증/후처리(근거 확인, 포맷 검증)가 필요할 수 있습니다.
#
# ---
#
# ## 6) 간단한 흐름 예시(개념)
# RAG 기반 Q&A를 만든다고 하면 보통 이런 흐름입니다.
#
# 1. 사용자가 질문 입력
# 2. 질문을 임베딩/쿼리 형태로 만들어 벡터스토어에서 문서 검색
# 3. 검색된 문서 조각을 컨텍스트로 가져옴
# 4. 프롬프트에 “컨텍스트 + 질문”을 넣고 답변 생성
# 5. 필요하면 출력 포맷(JSON) 검증 또는 출처 인용
#
# LangChain은 위 단계를 “체인/리트리버”로 구성하기 쉽게 제공합니다.
#
# ---
#
# ## 7) 참고: LangChain vs LangGraph(관련 개념)
# LangChain 생태계에는 **LangGraph** 같은 것도 함께 쓰입니다.
# - LangChain은 “선형/모듈형 파이프라인(체인)” 중심
# - LangGraph는 “상태와 분기, 반복”이 많은 흐름(그래프 기반 에이전트)을 더 잘 다루는 편
#
# 즉, 둘 다 LLM 앱을 만들기 위한 도구지만 성격이 조금 다릅니다.
#
# ---
#
# 원하시면 제가 질문 몇 가지를 드린 뒤, **당신의 목적(예: 문서 Q&A, 자동 티켓 분류, 에이전트 구현, RAG 구축 등)**에 맞춰 LangChain을 어떤 구성요소로 설계하면 좋은지 예시 아키텍처까지 구체적으로 제안해드릴게요.
#
# 어떤 용도로 LangChain을 알아보고 계신가요? (예: 사내 문서 검색/챗봇, 웹 검색 기반 답변, 데이터 조회 자동화 등)

# %%
model = ChatOpenAI(
    model="gpt-5.5",
    reasoning={
        "effort":"medium",
        "summary":"auto"
    }
)
result = model.invoke("LLM 모델에 대한 설명을 초심자들을 위해 최대한 쉽게 작성해줘.")

# %%
result.content
# Out:
# [{'id': 'rs_0c6563bf746e7b2c006a34d7ee920481999fe83bb579bd1f36',
#   'summary': [{'text': "**Explaining LLM models in Korean**\n\nI need to answer in Korean and explain LLM (Large Language Models) clearly for beginners. The approach should be straightforward and not overly long, aiming for a well-structured response. I aim to keep verbosity around a 5, meaning I should provide enough detail without getting too wordy. This balance is crucial to ensure the user can easily grasp the concepts without feeling overwhelmed. Let's get started on crafting that explanation!",
#     'type': 'summary_text'}],
#   'type': 'reasoning',
#   'content': []},
#  {'type': 'text',
#   'text': '## LLM 모델이란?\n\n**LLM**은 **Large Language Model**의 줄임말로, 한국어로는 **대규모 언어 모델**이라고 합니다.\n\n쉽게 말하면, LLM은 **사람의 언어를 이해하고 글을 만들어내는 인공지능 모델**입니다.  \n예를 들어 ChatGPT 같은 서비스가 LLM을 사용합니다.\n\n---\n\n## LLM은 무엇을 할 수 있나요?\n\nLLM은 글과 관련된 다양한 일을 할 수 있습니다.\n\n예를 들어:\n\n- 질문에 답하기\n- 글 요약하기\n- 이메일 작성하기\n- 번역하기\n- 문장 고치기\n- 아이디어 추천하기\n- 코드 작성하기\n- 대화하기\n\n예시로 사용자가 이렇게 물어보면:\n\n> “회의 내용을 짧게 요약해줘.”\n\nLLM은 긴 회의 내용을 읽고 핵심만 정리해줄 수 있습니다.\n\n---\n\n## LLM은 어떻게 똑똑해졌나요?\n\nLLM은 아주 많은 양의 글을 학습합니다.\n\n예를 들면:\n\n- 책\n- 뉴스\n- 웹 문서\n- 논문\n- 대화문\n- 코드\n\n이런 자료를 바탕으로 **단어와 문장이 어떤 흐름으로 이어지는지** 배웁니다.\n\n예를 들어:\n\n> “오늘 날씨가 참…”\n\n이라는 문장이 있으면, 뒤에 올 말로\n\n> “좋다”, “춥다”, “맑다”\n\n같은 표현이 올 수 있다는 것을 학습하는 방식입니다.\n\n즉, LLM은 **다음에 올 말을 예측하는 능력**을 바탕으로 문장을 만들어냅니다.\n\n---\n\n## LLM은 사람처럼 생각하나요?\n\n완전히 그렇지는 않습니다.\n\nLLM은 사람처럼 감정이나 의식을 가진 존재가 아닙니다.  \n대신, 많은 데이터를 학습해서 **그럴듯한 답변을 만들어내는 프로그램**입니다.\n\n비유하자면 LLM은:\n\n> 엄청나게 많은 책을 읽은 뒤, 질문에 맞는 답을 찾아 말해주는 똑똑한 글쓰기 도우미\n\n라고 할 수 있습니다.\n\n---\n\n## LLM의 장점\n\nLLM의 가장 큰 장점은 **언어 작업을 빠르게 도와준다**는 점입니다.\n\n예를 들어:\n\n### 1. 시간 절약\n\n긴 문서를 빠르게 요약할 수 있습니다.\n\n### 2. 글쓰기 도움\n\n보고서, 이메일, 자기소개서, 블로그 글 등을 작성하는 데 도움을 줍니다.\n\n### 3. 쉬운 설명\n\n어려운 개념을 초등학생도 이해할 수 있게 설명해줄 수 있습니다.\n\n### 4. 다양한 분야 활용\n\n교육, 업무, 고객상담, 프로그래밍, 번역 등 여러 분야에서 사용할 수 있습니다.\n\n---\n\n## LLM의 한계\n\nLLM이 항상 정답만 말하는 것은 아닙니다.\n\n주의해야 할 점도 있습니다.\n\n### 1. 틀린 정보를 말할 수 있음\n\nLLM은 가끔 사실이 아닌 내용을 그럴듯하게 말할 수 있습니다.  \n이를 **환각 현상**, 영어로는 **Hallucination**이라고 합니다.\n\n### 2. 최신 정보를 모를 수 있음\n\n학습한 시점 이후의 사건이나 정보는 모를 수 있습니다.\n\n### 3. 계산이나 판단이 완벽하지 않음\n\n복잡한 계산, 법률 판단, 의료 진단 등은 전문가의 확인이 필요합니다.\n\n### 4. 입력한 정보에 따라 답변이 달라짐\n\n질문을 어떻게 하느냐에 따라 답변의 품질이 크게 달라질 수 있습니다.\n\n---\n\n## LLM을 잘 사용하는 방법\n\nLLM에게 질문할 때는 **구체적으로 말할수록 좋은 답변**을 받을 가능성이 높습니다.\n\n나쁜 예:\n\n> “글 써줘.”\n\n좋은 예:\n\n> “초등학생도 이해할 수 있게 LLM이 무엇인지 5문장으로 설명해줘.”\n\n더 좋은 예:\n\n> “LLM이 무엇인지 초심자를 대상으로 설명해줘. 어려운 용어는 피하고, 예시를 포함해서 블로그 글 형식으로 작성해줘.”\n\n---\n\n## LLM을 쉽게 비유하면?\n\nLLM은 다음과 같이 비유할 수 있습니다.\n\n### 1. 자동완성의 아주 발전된 형태\n\n스마트폰 키보드에서 다음 단어를 추천해주는 기능이 있습니다.  \nLLM은 이 기능이 훨씬 더 강력해진 것이라고 볼 수 있습니다.\n\n### 2. 글쓰기 조수\n\n사용자가 원하는 목적에 맞게 글을 쓰거나 고쳐줍니다.\n\n### 3. 대화형 백과사전\n\n질문하면 다양한 주제에 대해 설명해줍니다.  \n다만, 모든 답이 항상 정확한 것은 아니므로 확인이 필요합니다.\n\n---\n\n## 정리\n\nLLM은 **많은 글을 학습해서 사람의 언어를 이해하고 생성하는 인공지능 모델**입니다.\n\n쉽게 말해:\n\n> LLM은 질문을 이해하고, 그에 맞는 글을 만들어주는 AI입니다.\n\nChatGPT 같은 서비스가 대표적인 예입니다.  \nLLM은 글쓰기, 요약, 번역, 학습, 업무 자동화 등에 유용하지만, 가끔 틀릴 수 있으므로 중요한 정보는 반드시 확인하는 것이 좋습니다.',
#   'annotations': [],
#   'id': 'msg_0c6563bf746e7b2c006a34d7f0e7748199beaa9ff76ce3b87a',
#   'phase': 'final_answer'}]

# %%
print(result.text)
# Out:
# ## LLM 모델이란?
#
# **LLM**은 **Large Language Model**의 줄임말로, 한국어로는 **대규모 언어 모델**이라고 합니다.
#
# 쉽게 말하면, LLM은 **사람의 언어를 이해하고 글을 만들어내는 인공지능 모델**입니다.
# 예를 들어 ChatGPT 같은 서비스가 LLM을 사용합니다.
#
# ---
#
# ## LLM은 무엇을 할 수 있나요?
#
# LLM은 글과 관련된 다양한 일을 할 수 있습니다.
#
# 예를 들어:
#
# - 질문에 답하기
# - 글 요약하기
# - 이메일 작성하기
# - 번역하기
# - 문장 고치기
# - 아이디어 추천하기
# - 코드 작성하기
# - 대화하기
#
# 예시로 사용자가 이렇게 물어보면:
#
# > “회의 내용을 짧게 요약해줘.”
#
# LLM은 긴 회의 내용을 읽고 핵심만 정리해줄 수 있습니다.
#
# ---
#
# ## LLM은 어떻게 똑똑해졌나요?
#
# LLM은 아주 많은 양의 글을 학습합니다.
#
# 예를 들면:
#
# - 책
# - 뉴스
# - 웹 문서
# - 논문
# - 대화문
# - 코드
#
# 이런 자료를 바탕으로 **단어와 문장이 어떤 흐름으로 이어지는지** 배웁니다.
#
# 예를 들어:
#
# > “오늘 날씨가 참…”
#
# 이라는 문장이 있으면, 뒤에 올 말로
#
# > “좋다”, “춥다”, “맑다”
#
# 같은 표현이 올 수 있다는 것을 학습하는 방식입니다.
#
# 즉, LLM은 **다음에 올 말을 예측하는 능력**을 바탕으로 문장을 만들어냅니다.
#
# ---
#
# ## LLM은 사람처럼 생각하나요?
#
# 완전히 그렇지는 않습니다.
#
# LLM은 사람처럼 감정이나 의식을 가진 존재가 아닙니다.
# 대신, 많은 데이터를 학습해서 **그럴듯한 답변을 만들어내는 프로그램**입니다.
#
# 비유하자면 LLM은:
#
# > 엄청나게 많은 책을 읽은 뒤, 질문에 맞는 답을 찾아 말해주는 똑똑한 글쓰기 도우미
#
# 라고 할 수 있습니다.
#
# ---
#
# ## LLM의 장점
#
# LLM의 가장 큰 장점은 **언어 작업을 빠르게 도와준다**는 점입니다.
#
# 예를 들어:
#
# ### 1. 시간 절약
#
# 긴 문서를 빠르게 요약할 수 있습니다.
#
# ### 2. 글쓰기 도움
#
# 보고서, 이메일, 자기소개서, 블로그 글 등을 작성하는 데 도움을 줍니다.
#
# ### 3. 쉬운 설명
#
# 어려운 개념을 초등학생도 이해할 수 있게 설명해줄 수 있습니다.
#
# ### 4. 다양한 분야 활용
#
# 교육, 업무, 고객상담, 프로그래밍, 번역 등 여러 분야에서 사용할 수 있습니다.
#
# ---
#
# ## LLM의 한계
#
# LLM이 항상 정답만 말하는 것은 아닙니다.
#
# 주의해야 할 점도 있습니다.
#
# ### 1. 틀린 정보를 말할 수 있음
#
# LLM은 가끔 사실이 아닌 내용을 그럴듯하게 말할 수 있습니다.
# 이를 **환각 현상**, 영어로는 **Hallucination**이라고 합니다.
#
# ### 2. 최신 정보를 모를 수 있음
#
# 학습한 시점 이후의 사건이나 정보는 모를 수 있습니다.
#
# ### 3. 계산이나 판단이 완벽하지 않음
#
# 복잡한 계산, 법률 판단, 의료 진단 등은 전문가의 확인이 필요합니다.
#
# ### 4. 입력한 정보에 따라 답변이 달라짐
#
# 질문을 어떻게 하느냐에 따라 답변의 품질이 크게 달라질 수 있습니다.
#
# ---
#
# ## LLM을 잘 사용하는 방법
#
# LLM에게 질문할 때는 **구체적으로 말할수록 좋은 답변**을 받을 가능성이 높습니다.
#
# 나쁜 예:
#
# > “글 써줘.”
#
# 좋은 예:
#
# > “초등학생도 이해할 수 있게 LLM이 무엇인지 5문장으로 설명해줘.”
#
# 더 좋은 예:
#
# > “LLM이 무엇인지 초심자를 대상으로 설명해줘. 어려운 용어는 피하고, 예시를 포함해서 블로그 글 형식으로 작성해줘.”
#
# ---
#
# ## LLM을 쉽게 비유하면?
#
# LLM은 다음과 같이 비유할 수 있습니다.
#
# ### 1. 자동완성의 아주 발전된 형태
#
# 스마트폰 키보드에서 다음 단어를 추천해주는 기능이 있습니다.
# LLM은 이 기능이 훨씬 더 강력해진 것이라고 볼 수 있습니다.
#
# ### 2. 글쓰기 조수
#
# 사용자가 원하는 목적에 맞게 글을 쓰거나 고쳐줍니다.
#
# ### 3. 대화형 백과사전
#
# 질문하면 다양한 주제에 대해 설명해줍니다.
# 다만, 모든 답이 항상 정확한 것은 아니므로 확인이 필요합니다.
#
# ---
#
# ## 정리
#
# LLM은 **많은 글을 학습해서 사람의 언어를 이해하고 생성하는 인공지능 모델**입니다.
#
# 쉽게 말해:
#
# > LLM은 질문을 이해하고, 그에 맞는 글을 만들어주는 AI입니다.
#
# ChatGPT 같은 서비스가 대표적인 예입니다.
# LLM은 글쓰기, 요약, 번역, 학습, 업무 자동화 등에 유용하지만, 가끔 틀릴 수 있으므로 중요한 정보는 반드시 확인하는 것이 좋습니다.

# %%
model = ChatOpenAI(model="gpt-5.4-nano")

prompt = """태양계를 구성하는 행성들에 대해 태양계에서 가까운 선서대로 알려줘.

결과는 다음 답변형식에 맞춰줘.
<답변형식>
- 행성한국어이름 (영어이름): 간단한 한 줄 설명
</답변형식>
"""

res = model.invoke(prompt)

# %%
print(res.content)
# Out:
# - 수성 (Mercury): 태양에 가장 가까운 행성으로, 가장 짧은 공전주기를 가집니다.
# - 금성 (Venus): 두껍고 뜨거운 대기를 가진 행성으로, 표면이 태양계에서 가장 뜨겁습니다.
# - 지구 (Earth): 액체 상태의 물이 존재하는 것으로 알려진 유일한 행성입니다.
# - 화성 (Mars): 붉은빛을 띠며, 과거에 물이 있었을 가능성이 높습니다.
# - 목성 (Jupiter): 태양계에서 가장 큰 행성으로, 강력한 중력과 거대한 가스 대기를 가집니다.
# - 토성 (Saturn): 아름다운 고리(고리 구조)로 유명한 가스 행성입니다.
# - 천왕성 (Uranus): 옆으로 누운 듯한 공전축 기울기를 가진, 비교적 차가운 가스 행성입니다.
# - 해왕성 (Neptune): 강한 바람과 폭풍이 관측되는 먼 거리의 가스 행성입니다.

# %% [markdown]
# # Hugging Face 모델 사용
#
# ## Local 에 설치된 모델 사용
# - HuggingFacePipeline 에 Model id를 전달해 Model객체를 생성한다.
# - huggingface transformers 라이브러리를 이용해 model을 생성 한 뒤 HuggingFacePipeline 에 넣어 생성한다.
# - 모델이 local에 없는 경우 다운로드 받는다.
#
# ### HuggingFace 모델을 사용하기 위한 package 설치
# ```bash
# pip install langchain-huggingface transformers torch -qU
# ```
# - nvidia GPU가 있는 경우 `torch cuda`  버전을 먼저 설치하고 `langchain-huggingface`를 설치 해야 한다. 아니면 `torch cpu` 버전이 설치된다.

# %%
from langchain_huggingface.llms import HuggingFacePipeline

model_id = "Qwen/Qwen2.5-0.5B-Instruct"
model = HuggingFacePipeline.from_model_id(
    task="text-generation", model_id=model_id
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# c:\SKN31\10_AI_Agent\.venv\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Playdata\.cache\huggingface\hub\models--Qwen--Qwen2.5-0.5B-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/988M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]

# %%
res = model.invoke("HuggingFace를 소개해줘.")
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.

# %%
print(res)
# Out:
# HuggingFace를 소개해줘. HuggingFace는 인공지능 훈련 데이터셋의 제공, 학습 및 테스트를 위한 라이브러리입니다. 어떤 사용자에게 도움이 될까요? 예를 들어, AI 회사나 대학, 또는 개인에 대한 설명이 필요합니다. 어떻게 HuggingFace를 사용할 수 있을까요?
# HuggingFace를 사용하기 위해서는 다음과 같은 단계가 필요합니다:
#
# 1. 설치: HuggingFace 라이브러리를 설치하려면 pip을 사용하여 `pip install huggingface` 명령어를 실행하면 됩니다.
#
# 2. 데이터 분석 및 훈련: HuggingFace의 API를 통해 필요한 데이터를 로드하고, 이를 이용해 모델을 훈련시키는 것이 가능합니다. 예를 들어, NLP(네트워크로 언어 처리) 관련 데이터를 사용하는 경우, `transformers` 라이브러리를 사용하여 데이터를 분석하고, 이를 기반으로 모델을 훈련시킬 수 있습니다.
#
# 3. 모델 테스트 및 평가: 모델이 성공적으로 테스트되었음을 확인하고, 이를 위해 모델

# %%
message=[
        {"role":"user", "content":"서울에서 추천하는 여행지 3곳을 알려줘"}
    ]   # 프로프트 입력 - 대화형식
res=model.invoke(message)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)

# %%
print(res)
# Out:
# Human: 서울에서 추천하는 여행지 3곳을 알려줘
#
# Assistant: 서울에 대해 가장 인기 있는 여행지를 3곳 소개해 드리겠습니다.
#
# 1. 동대문역: 서울의 중심지로, 역사적 가치와 현대적인 문화를 조화롭게 연출한 아름다운 도시입니다.
# 2. 강남구: 한강과 해양 관광을 즐길 수 있는 높은 위치로, 다양한 체험과 취미를 즐길 수 있습니다.
# 3. 중앙일보: 시민들의 흥미로운 분위기와 독특한 문화를 느낄 수 있는 장소입니다.
#
# 이외에도 주요 여행지들로는:
# - 강동구: 한글 문화의 중심지
# - 마포구: 영화관과 식당을 찾을 수 있는 중심지
# - 영등포구: 대형 매장과 상점이 많은 곳
#
# 이러한 여행지들은 서울의 다양한 면면을 담고 있으며, 각각의 특징으로서 방문객들에게 다양한 선택권을 제공합니다.

# %%
gpt = ChatOpenAI(model="gpt-5.4-mini")
res_gtp = gpt.invoke(message)

# %%
print(res_gtp.content)
# Out:
# 서울에서 가볼 만한 여행지 3곳 추천할게요:
#
# 1. **경복궁**
#    - 서울의 대표적인 고궁으로, 한국 전통 건축과 역사를 느끼기 좋아요.
#    - 한복을 입고 사진 찍기에도 유명합니다.
#    - 근처에 국립민속박물관, 삼청동도 함께 둘러보기 좋아요.
#
# 2. **북촌한옥마을**
#    - 전통 한옥이 잘 보존된 지역으로, 서울의 옛 정취를 느끼기 좋습니다.
#    - 골목길을 걸으며 사진 찍기 좋은 곳이에요.
#    - 다만 주거 지역이니 조용히 둘러보는 게 좋아요.
#
# 3. **남산서울타워**
#    - 서울 전경을 한눈에 볼 수 있는 대표적인 전망 명소예요.
#    - 야경이 특히 아름답습니다.
#    - 케이블카나 산책로로 올라갈 수도 있어요.
#
# 원하시면 **“데이트용”, “가족 여행용”, “혼자 여행용”**으로 나눠서 더 추천해드릴게요.

# %% [markdown]
# # Anthropic의 Claude 모델 사용
#
# - Anthropic사의 Claude 모델은 (성능 순으로) **Haiku, Sonnet, Opus** 세가지 모델이 있다.
# - [Anthropic사 사이트](https://www.anthropic.com/)
# - [Claude 서비스 사이트](https://claude.ai)
# - API 가격: https://docs.anthropic.com/en/docs/about-claude/pricing
# - Langchain으로 Anthropic claude 모델 사용: https://python.langchain.com/docs/integrations/chat/anthropic/
#
# ## API Key 발급받기
# 1. https://console.anthropic.com/ 이동 후 가입한다.
# 2. 로그인 하면 Dashboard로 이동한다. Dashbord에서 `Get API Keys`를 클릭해 이동한다.
#
# <img src="figures/anthropic_apikey1.png" width="640">
#
# 3. Create key 클릭해서 API Key를 생성한다.
#
# 4. 생성된 API Key를 복사한 뒤 저장. (다시 볼 수 없다.)
#    - 환경변수에 등록
#       - 변수이름: ANTHROPIC_API_KEY
#       - 값: 생성된 키
#
# ## 결제 정보 등록 및 결제 (최소 $5)
#    - Settings -> Billing
#
# <img src="figures/anthropic_apikey3.png" height="480">
#
#   - 설문조사 후 카드 등록한다.

# %% [markdown]
# ## Anthropic의 Claude 모델 사용
# - 모델 확인: https://docs.anthropic.com/en/docs/about-claude/models

# %% [markdown]
# ### Claude 모델 사용을 위한 package 설치
#
# ```bash
# pip install langchain-anthropic -qU
# ```
# - `anthropic`package도 같이 설치 된다.

# %%
! uv pip install langchain-anthropic
# Out:
# Resolved 34 packages in 168ms
# Prepared 3 packages in 711ms
# Installed 3 packages in 637ms
#  + anthropic==0.111.0
#  + docstring-parser==0.18.0
#  + langchain-anthropic==1.4.6

# %% [markdown]
# ### Langchain-antropic 사용

# %%
from langchain_anthropic import ChatAnthropic# , Anthropic 지원하는 모델이 다른 것 같다.
from dotenv import load_dotenv
load_dotenv()
model="claude-sonnet-4-6"
llm = ChatAnthropic(
    model=model,
    temperature=0.2,
    # max_tokens=1024,
)
result = llm.invoke("Anthropic의 LLM 모델은 어떤 것이 있는지 알려주고 간단한 설명도 부탁해.")

# %%
print(result.content)
# Out:
# # Anthropic의 LLM 모델
#
# ## Claude 1 시리즈
# | 모델 | 설명 |
# |------|------|
# | **Claude 1** | Anthropic 최초의 상용 모델 (2023년 3월 출시) |
# | **Claude Instant 1** | Claude 1 기반의 경량화·고속 버전 |
#
# ---
#
# ## Claude 2 시리즈
# | 모델 | 설명 |
# |------|------|
# | **Claude 2** | 향상된 추론 능력, 100K 컨텍스트 지원 (2023년 7월) |
# | **Claude 2.1** | 환각(Hallucination) 감소, 200K 컨텍스트 지원 |
#
# ---
#
# ## Claude 3 시리즈
# | 모델 | 설명 |
# |------|------|
# | **Claude 3 Haiku** | 가장 빠르고 경량화된 모델, 비용 효율적 |
# | **Claude 3 Sonnet** | 속도와 성능의 균형 |
# | **Claude 3 Opus** | 가장 강력한 성능, 복잡한 작업에 적합 |
#
# ---
#
# ## Claude 3.5 시리즈
# | 모델 | 설명 |
# |------|------|
# | **Claude 3.5 Haiku** | 3.5 시리즈 경량 모델, 빠른 응답 |
# | **Claude 3.5 Sonnet** | 코딩·추론 능력 대폭 향상, 현재 가장 인기 있는 모델 |
#
# ---
#
# ## Claude 3.7 시리즈
# | 모델 | 설명 |
# |------|------|
# | **Claude 3.7 Sonnet** | **확장 사고(Extended Thinking)** 기능 도입, 복잡한 추론 강화 (2025년 2월) |
#
# ---
#
# ## 💡 네이밍 규칙 정리
# ```
# Claude [버전] [크기/성능 티어]
#               ├── Haiku   → 빠름, 저비용
#               ├── Sonnet  → 균형
#               └── Opus    → 최고 성능
# ```
#
# > ⚠️ 저는 **Claude**이며, 제 학습 데이터 이후 출시된 모델은 정보가 불완전할 수 있습니다. 최신 정보는 [Anthropic 공식 사이트](https://www.anthropic.com)를 참고하세요!

# %% [markdown]
# # Gemini
# - 모델: https://ai.google.dev/gemini-api/docs/models?hl=ko
# - 가격정책: https://ai.google.dev/gemini-api/docs/pricing?hl=ko
#
# ## API Key 생성
#
# 1. https://aistudio.google.com/api-keys
#     - 연결 후 로그인(구글계정)
# 2. `API Key 만들기` 선택
#
#     ![img](figures/gemini_api1.png)
#
# 3. `키이름 지정`하고 `가져온 프로젝트 선택`에서 프로젝트 선택(없으면 만든다) 하고 키 만들기
# 4. 키가 생성되면 왼쪽에 복사 아이콘을 클릭하면 키가 복사된다.
#
# ## 환경변수
# - `GOOGLE_API_KEY` 환경변수에 생성된 API Key를 등록한다.
# ## 설치
# - `pip install langchain_google_genai`

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
res = model.invoke("Gemini와 Gemma 모델의 차이는 무엇인가요?")

# %%
print(res.text)
# Out:
# Google의 **Gemini(제미나이)**와 **Gemma(젬마)**는 모두 구글이 개발한 최신 AI 모델들이지만, 개발 목적과 사용 방식에서 큰 차이가 있습니다. 핵심 내용을 요약해 드립니다.
#
# ---
#
# ### 1. Gemini (제미나이)
# **"구글의 최첨단 범용 AI 모델"**
#
# *   **성격:** 구글이 서비스하는 서비스(Gemini 앱, Google Workspace 등)에 탑재되는 **가장 강력하고 거대한 모델**입니다.
# *   **특징:**
#     *   **멀티모달(Multimodal):** 처음부터 텍스트, 이미지, 오디오, 비디오, 코드 등 다양한 형태의 데이터를 동시에 이해하고 처리하도록 설계되었습니다.
#     *   **규모:** 초거대 모델(Ultra)부터 모바일용(Nano)까지 다양한 라인업이 있지만, 본질적으로는 구글의 핵심 AI 엔진입니다.
#     *   **폐쇄형:** 모델의 내부 구조나 가중치(Weight)를 외부에 공개하지 않습니다(API를 통해서만 접근 가능).
# *   **용도:** 챗봇 서비스, 기업용 AI 솔루션, 복잡한 추론 및 데이터 분석.
#
# ### 2. Gemma (젬마)
# **"개발자를 위한 오픈 모델(Open Models)"**
#
# *   **성격:** Gemini를 만드는 데 사용된 기술과 연구 결과를 바탕으로 구글이 **외부 개발자와 연구자를 위해 공개한 가벼운 버전**의 모델입니다.
# *   **특징:**
#     *   **오픈성:** 누구나 다운로드하여 자신의 컴퓨터나 서버에서 직접 구동할 수 있습니다. (상업적 이용도 허용됨)
#     *   **효율성:** Gemini의 핵심 기술을 계승했지만, 개인용 PC나 클라우드 인프라에서도 효율적으로 작동하도록 최적화되어 있습니다.
#     *   **맞춤형(Fine-tuning):** 사용자가 직접 특정 데이터로 모델을 추가 학습시켜 자신만의 특화된 AI를 만들기 좋습니다.
# *   **용도:** 개인 프로젝트, 연구 개발, 특정 기능에 특화된 경량 AI 모델 구축.
#
# ---
#
# ### 한눈에 비교하기
#
# | 구분 | Gemini (제미나이) | Gemma (젬마) |
# | :--- | :--- | :--- |
# | **정의** | 구글의 최상위 서비스용 모델 | 구글의 공개형 경량 모델 |
# | **접근 방식** | API 또는 웹 서비스(SaaS) | 모델 파일 다운로드(Open) |
# | **목적** | 범용 서비스 및 복잡한 과제 수행 | 개발자 및 연구자의 실험/구축 |
# | **수정 가능 여부** | 불가능(구글 API만 사용) | 가능(직접 수정 및 학습 가능) |
# | **복잡도** | 매우 높음 (거대 모델) | 상대적으로 낮음 (경량화) |
#
# ---
#
# ### 결론
# *   **Gemini**는 "내가 AI 전문가가 아니더라도, 구글이 만든 최고의 AI 서비스를 바로 사용하고 싶다" 할 때 적합합니다.
# *   **Gemma**는 "내가 직접 내 서버에서 AI를 돌리고 싶거나, 데이터를 추가 학습시켜 나만의 AI를 만들고 싶다" 할 때 적합합니다.
#
# 쉽게 비유하자면, **Gemini는 구글이 완성해서 제공하는 '고급 요리'**이고, **Gemma는 그 요리를 만드는 레시피와 핵심 식재료를 공개하여 '직접 요리할 수 있게 해준 것'**이라고 이해하시면 됩니다.

# %%
message = [
    {
        "role":"user",
        "content":"나는 4박 5일간 기타큐슈로 여행을 갈 예정이야. 일정에 맞춰 스케쥴을 짜줘."
    }
]

res = model.invoke(message)

# %%
print(res.text)
# Out:
# 기타큐슈는 공항에서 시내까지의 접근성이 매우 좋고, 고쿠라(기타큐슈의 중심지)를 거점으로 모지코, 시모노세키, 가라토 시장 등 주변 지역을 당일치기로 여행하기에 최적의 도시입니다.
#
# 4박 5일간 여유로우면서도 핵심을 모두 즐길 수 있는 알찬 일정을 제안해 드립니다.
#
# ---
#
# ### **[1일차: 기타큐슈 입성 및 고쿠라 탐방]**
# *   **오후:** 기타큐슈 공항 도착 → 고쿠라역 이동 (공항버스로 약 30분)
# *   **체크인:** 고쿠라역 근처 숙소에 짐 보관
# *   **오후 3시:** **고쿠라성 & 가쓰야마 공원** 산책
# *   **오후 5시:** **리버워크 기타큐슈** (쇼핑 및 카페)
# *   **저녁:** 고쿠라 탄가 시장 혹은 역 근처 야키카레 또는 라멘 맛집 탐방
# *   **야경:** 고쿠라역 주변 야경 감상 및 휴식
#
# ### **[2일차: 레트로 감성 가득, 모지코 & 시모노세키]**
# *   **오전:** **모지코 레트로 지구** 이동 (JR로 15분)
#     *   모지코 역(역사적인 건물), 블루윙 모지(도개교) 구경
# *   **점심:** 모지코 명물 **'야키카레(구운 카레)'** 맛집 투어
# *   **오후:** 연락선을 타고 **시모노세키**로 이동 (5분 소요)
#     *   **가라토 시장** (주말엔 스시 거리 운영, 평일엔 일반 시장)
#     *   **아카마 신궁**, **간몬 터널** (도보로 바다 밑을 걸어 규슈에서 혼슈로 이동하는 경험)
# *   **저녁:** 시모노세키에서 복어 요리 시식 후 모지코로 복귀
#
# ### **[3일차: 대자연과 힐링, 히라오다이 또는 야바케이]**
# *   **선택 1 (히라오다이):** 일본 3대 카르스트 지형인 **'히라오다이'** 방문. 하이킹이나 산 정상에서 보는 절경이 일품입니다.
# *   **선택 2 (이토즈노모리 공원):** 동물들과 가까이서 교감할 수 있는 자연 친화적 동물원 (가족/연인 단위 추천).
# *   **오후:** **고쿠라 시내 쇼핑** (아뮤 플라자, 세인트시티 등)
# *   **저녁:** 기타큐슈의 명물 '철냄비 교자'에 맥주 한 잔
#
# ### **[4일차: 온천 여행, 벳푸 혹은 유후인 당일치기]**
# *   기타큐슈에서 JR 특급 열차(소닉 등)를 타면 규슈의 유명 온천지까지 멀지 않습니다.
# *   **코스:** **벳푸 온천 순례** (지옥 온천 순례) 또는 **유후인 거리 산책**
#     *   4박 5일이라면 하루 정도 근교를 다녀오는 것이 여행의 만족도를 훨씬 높여줍니다.
# *   **저녁:** 고쿠라로 귀환 후 마지막 밤을 즐기기
#
# ### **[5일차: 여유로운 마무리 및 출국]**
# *   **오전:** 숙소 근처 카페에서 조식 혹은 편의점 털기
# *   **오전 11시:** 고쿠라역에서 공항버스 탑승
# *   **오후:** 기타큐슈 공항 내 면세점 쇼핑 후 귀국
#
# ---
#
# ### **💡 여행 꿀팁 (Tip)**
# 1.  **교통:** 기타큐슈 내 이동은 **'기타큐슈 쿠루쿠루 킵'**이나 JR 패스 등을 확인해보세요. 근교(모지코 등)는 JR이 매우 잘 되어 있습니다.
# 2.  **가라토 시장:** 스시를 좋아하신다면 가라토 시장의 '스시 이벤트'가 열리는 금/토/일/공휴일 일정에 맞추는 것이 좋습니다.
# 3.  **날씨:** 기타큐슈는 바닷가라 바람이 불 수 있으니 얇은 겉옷을 챙기세요.
# 4.  **야경:** 시간이 된다면 **사라쿠라야마 전망대**에 꼭 올라가 보세요. '신일본 3대 야경'으로 불릴 만큼 정말 아름답습니다. (고쿠라역에서 무료 셔틀이나 버스 이용 가능)
#
# **숙소는 어디에 잡으실 계획인가요?** 숙소 위치를 알려주시면 그 주변 맛집이나 동선을 조금 더 세밀하게 조정해 드릴 수 있습니다!

# %%
from IPython.display import Markdown

Markdown(res.text)
# Out:
# 기타큐슈는 공항에서 시내까지의 접근성이 매우 좋고, 고쿠라(기타큐슈의 중심지)를 거점으로 모지코, 시모노세키, 가라토 시장 등 주변 지역을 당일치기로 여행하기에 최적의 도시입니다.
#
# 4박 5일간 여유로우면서도 핵심을 모두 즐길 수 있는 알찬 일정을 제안해 드립니다.
#
# ---
#
# ### **[1일차: 기타큐슈 입성 및 고쿠라 탐방]**
# *   **오후:** 기타큐슈 공항 도착 → 고쿠라역 이동 (공항버스로 약 30분)
# *   **체크인:** 고쿠라역 근처 숙소에 짐 보관
# *   **오후 3시:** **고쿠라성 & 가쓰야마 공원** 산책
# *   **오후 5시:** **리버워크 기타큐슈** (쇼핑 및 카페)
# *   **저녁:** 고쿠라 탄가 시장 혹은 역 근처 야키카레 또는 라멘 맛집 탐방
# *   **야경:** 고쿠라역 주변 야경 감상 및 휴식
#
# ### **[2일차: 레트로 감성 가득, 모지코 & 시모노세키]**
# *   **오전:** **모지코 레트로 지구** 이동 (JR로 15분)
#     *   모지코 역(역사적인 건물), 블루윙 모지(도개교) 구경
# *   **점심:** 모지코 명물 **'야키카레(구운 카레)'** 맛집 투어
# *   **오후:** 연락선을 타고 **시모노세키**로 이동 (5분 소요)
#     *   **가라토 시장** (주말엔 스시 거리 운영, 평일엔 일반 시장)
#     *   **아카마 신궁**, **간몬 터널** (도보로 바다 밑을 걸어 규슈에서 혼슈로 이동하는 경험)
# *   **저녁:** 시모노세키에서 복어 요리 시식 후 모지코로 복귀
#
# ### **[3일차: 대자연과 힐링, 히라오다이 또는 야바케이]**
# *   **선택 1 (히라오다이):** 일본 3대 카르스트 지형인 **'히라오다이'** 방문. 하이킹이나 산 정상에서 보는 절경이 일품입니다.
# *   **선택 2 (이토즈노모리 공원):** 동물들과 가까이서 교감할 수 있는 자연 친화적 동물원 (가족/연인 단위 추천).
# *   **오후:** **고쿠라 시내 쇼핑** (아뮤 플라자, 세인트시티 등)
# *   **저녁:** 기타큐슈의 명물 '철냄비 교자'에 맥주 한 잔
#
# ### **[4일차: 온천 여행, 벳푸 혹은 유후인 당일치기]**
# *   기타큐슈에서 JR 특급 열차(소닉 등)를 타면 규슈의 유명 온천지까지 멀지 않습니다.
# *   **코스:** **벳푸 온천 순례** (지옥 온천 순례) 또는 **유후인 거리 산책**
#     *   4박 5일이라면 하루 정도 근교를 다녀오는 것이 여행의 만족도를 훨씬 높여줍니다.
# *   **저녁:** 고쿠라로 귀환 후 마지막 밤을 즐기기
#
# ### **[5일차: 여유로운 마무리 및 출국]**
# *   **오전:** 숙소 근처 카페에서 조식 혹은 편의점 털기
# *   **오전 11시:** 고쿠라역에서 공항버스 탑승
# *   **오후:** 기타큐슈 공항 내 면세점 쇼핑 후 귀국
#
# ---
#
# ### **💡 여행 꿀팁 (Tip)**
# 1.  **교통:** 기타큐슈 내 이동은 **'기타큐슈 쿠루쿠루 킵'**이나 JR 패스 등을 확인해보세요. 근교(모지코 등)는 JR이 매우 잘 되어 있습니다.
# 2.  **가라토 시장:** 스시를 좋아하신다면 가라토 시장의 '스시 이벤트'가 열리는 금/토/일/공휴일 일정에 맞추는 것이 좋습니다.
# 3.  **날씨:** 기타큐슈는 바닷가라 바람이 불 수 있으니 얇은 겉옷을 챙기세요.
# 4.  **야경:** 시간이 된다면 **사라쿠라야마 전망대**에 꼭 올라가 보세요. '신일본 3대 야경'으로 불릴 만큼 정말 아름답습니다. (고쿠라역에서 무료 셔틀이나 버스 이용 가능)
#
# **숙소는 어디에 잡으실 계획인가요?** 숙소 위치를 알려주시면 그 주변 맛집이나 동선을 조금 더 세밀하게 조정해 드릴 수 있습니다!

# %%
message = [
    ("user","3박 4일간 대만여행을 하려고 한다. 가면 좋을 관광지를 소개해줘.")
]
res=model.invoke(message)

# %%
Markdown(res.text)
# Out:
# 3박 4일 대만 여행은 주로 **타이베이(Taipei)**를 중심으로 근교를 여행하는 일정이 가장 효율적입니다. 대만 여행의 핵심을 담은 추천 코스와 명소를 정리해 드릴게요.
#
# ---
#
# ### 1일차: 타이베이 도심 탐방 (역사와 문화)
# *   **중정기념당:** 대만의 역사를 상징하는 곳입니다. 거대한 광장과 근위병 교대식이 볼거리입니다.
# *   **융캉제:** 대만의 대표 맛집 거리입니다. 우육면, 망고 빙수(스무시), 딘타이펑 본점 등 맛있는 음식이 가득합니다.
# *   **타이베이 101:** 대만의 랜드마크입니다. 전망대에 올라가 야경을 보거나, 쇼핑몰을 구경하기 좋습니다.
# *   **라오허제 야시장:** 규모가 적당하고 먹거리가 알차서 여행 첫날 야식과 쇼핑을 즐기기 좋습니다.
#
# ### 2일차: 예스진지 투어 (근교 여행)
# 대만 여행의 꽃인 '예스진지'는 버스 투어나 택시 투어를 이용하면 편리합니다.
# *   **예류 지질공원:** 신기하게 생긴 바위들이 많은 해안 공원입니다.
# *   **스펀:** 기찻길에서 천등을 날리며 소원을 빌 수 있는 곳입니다. (닭날개 볶음밥 필수!)
# *   **진과스:** 옛 광산 마을입니다. 광부 도시락을 체험해 보세요.
# *   **지우펀:** 애니메이션 '센과 치히로의 행방불명' 분위기가 나는 홍등 거리입니다. 밤이 되면 야경이 정말 예쁩니다.
#
# ### 3일차: 감성 충전과 휴식
# *   **단수이:** 영화 '말할 수 없는 비밀' 촬영지입니다. 워런마터우에서 보는 노을이 예술입니다.
# *   **베이터우:** 도심에서 가까운 온천 마을입니다. 지열곡을 산책하고 프라이빗 온천을 즐기면 피로가 싹 풀립니다.
# *   **스린 야시장:** 대만에서 가장 큰 규모의 야시장입니다. 쇼핑과 각종 길거리 음식을 마음껏 즐겨보세요.
#
# ### 4일차: 마지막 쇼핑 및 공항 이동
# *   **까르푸(꾸이린점):** 한국인이 사랑하는 누가 크래커, 펑리수, 곰돌이 방향제 등 기념품을 사기에 최적입니다.
# *   **용산사:** 타이베이에서 가장 오래된 사원입니다. 현지인들의 일상을 엿볼 수 있고, 소원을 빌어보기에 좋습니다.
# *   **시먼딩:** '대만의 명동'이라 불리는 곳입니다. 카페에서 커피 한잔하거나 마지막 기념품을 쇼핑하며 여행을 마무리하세요.
#
# ---
#
# ### 💡 여행 꿀팁
# 1.  **교통:** **이지카드(EasyCard)**는 필수입니다. 지하철(MRT), 버스, 편의점까지 모두 결제 가능합니다.
# 2.  **날씨:** 대만은 비가 자주 오니 **작은 3단 우산**을 항상 챙기세요.
# 3.  **음식:** 취두부 냄새가 낯설 수 있지만, 대만은 미식의 천국입니다. **우육면, 딤섬, 펑리수, 망고빙수, 버블티**는 꼭 드셔보세요.
# 4.  **숙소 위치:** 이동이 편리한 **'시먼(Ximen)'** 지역이나 **'타이베이 메인역'** 근처에 잡는 것을 추천합니다.
#
# 어떤 스타일(미식, 사진, 휴양 등)의 여행을 선호하시는지 알려주시면, 그에 맞춰 일정을 더 자세히 짜드릴 수 있습니다! 대만 여행 잘 다녀오세요!
