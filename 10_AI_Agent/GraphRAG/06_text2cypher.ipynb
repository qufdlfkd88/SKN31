# %%
import os
from dotenv import load_dotenv

load_dotenv()

print(
    os.getenv("NEO4J_URI"),
    os.getenv("NEO4J_USERNAME"),
    os.getenv("NEO4J_PASSWORD"),
    os.getenv("NEO4J_DATABASE")
)
# Out:
# neo4j://127.0.0.1:7687 neo4j 11111111 movie-info

# %%
from langchain_neo4j import Neo4jGraph
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from pprint import pprint

graph = Neo4jGraph()

# %% [markdown]
# # Text-to-Cypher
#
# - Text-to-Cypher는 자연어 질의를 Neo4j 데이터베이스 쿼리 언어인 Cypher로 변환하여 지식 그래프를 효과적으로 검색할 수 있는 기술을 말한다.
#
#
# ## 자연어를 cypher query로 변환

# %%
################
#  직접 구현
################

graph.refresh_schema()  # 디비 스키마 다시 읽어온다.
schema = graph.schema   # str
print(schema)
vector_index = graph.query("SHOW VECTOR INDEXES")
print(vector_index)
# Out:
# Node properties:
# Movie {id: STRING, title: STRING, rating: FLOAT, released: LOCAL_DATE_TIME, overview: STRING, runtime: INTEGER, tagline: STRING}
# Person {id: STRING, name: STRING}
# Genre {id: STRING, name: STRING}
# Relationship properties:
#
# The relationships:
# (:Movie)-[:IN_GENRE]->(:Genre)
# (:Person)-[:ACTED_IN]->(:Movie)
# (:Person)-[:DIRECTED]->(:Movie)
# []

# %%
model = ChatOpenAI(model="gpt-5.4-mini")
prompt_template = PromptTemplate(
    template="""
<instruction>
다음 그래프 스키마를 참고해서 질문에 맞는 cypher 쿼리를 작성하세요.
</instruction>

<input_data>
    <schema>{schema}</schema>
    <question>{query}</question>
</input_data>

<constraint>
- 질문과 schema 가 맞지 않으면 vector-index를 참고해서 vector 검색쿼리를 생성한다.
- 생성한 쿼리만 문자열로 반환한다. 설명과 같은 다른 어떠한 것도 추가로 작성하지 않는다.
- 만약 감독의 이름, 영화제목, 배우이름이 쿼리문에 들어갈 경우 영어로 바꿔서 입력한다.
</constraint>
"""
)

query_chain = prompt_template | model | StrOutputParser()

def text_to_query(question: str, schema: str) -> str:
    """자연어 질의를 cypher query로 변환하는 함수"""
    return query_chain.invoke({"schema":schema, "query":question})

# %%
query = "톰 행크스가 출연한 영화는?"
query = "톰 행크스가 출연한 영화들의 감독들은 누구인가요?"
query = "2차 세계대전을 배경으로 치열한 전투를 보여주는 영화의 제목과 그 영화 감독, 배우를 알려줘."

cypher_query = text_to_query(query, schema)
print(cypher_query)

print("생성된 쿼리로 조회")
resp = graph.query(cypher_query)
print("-------------조회결과--------------------")
pprint(resp)
# Out:
# MATCH (m:Movie)-[:IN_GENRE]->(:Genre)
# WHERE toLower(m.overview) CONTAINS 'world war ii' OR toLower(m.overview) CONTAINS 'world war 2' OR toLower(m.overview) CONTAINS 'war'
# MATCH (d:Person)-[:DIRECTED]->(m)
# MATCH (a:Person)-[:ACTED_IN]->(m)
# RETURN m.title AS movie_title, d.name AS director_name, collect(DISTINCT a.name) AS actor_names
# 생성된 쿼리로 조회
# -------------조회결과--------------------
# [{'actor_names': ['John Goodman',
#                   'Mary Elizabeth Winstead',
#                   'Bradley Cooper',
#                   'Douglas M. Griffin',
#                   'John Gallagher Jr.'],
#   'director_name': 'Dan Trachtenberg',
#   'movie_title': '10 Cloverfield Lane'},
#  {'actor_names': ['Paul Dano',
#                   'Chiwetel Ejiofor',
#                   'Michael Fassbender',
#                   'Benedict Cumberbatch',
#                   "Lupita Nyong'o"],
#   'director_name': 'Steve McQueen',
#   'movie_title': '12 Years a Slave'},
#  {'actor_names': ['Robert De Niro',
#                   'Edward Burns',
#                   'Charlize Theron',
#                   'Avery Brooks',
#                   'Kelsey Grammer'],
#   'director_name': 'John Herzfeld',
#   'movie_title': '15 Minutes'},
#  {'actor_names': ['Joan Chen',
#                   'Jackie Chan',
#                   'Li Bingbing',
#                   'Jaycee Chan',
#                   'Sun Chun'],
#   'director_name': 'Jackie Chan',
#   'movie_title': '1911'},
#  {'actor_names': ['Joan Chen',
#                   'Jackie Chan',
#                   'Li Bingbing',
#                   'Jaycee Chan',
#                   'Sun Chun'],
#   'director_name': '张立',
#   'movie_title': '1911'},
#  {'actor_names': ['Joan Chen',
#                   'Jackie Chan',
#                   'Li Bingbing',
#                   'Jaycee Chan',
#                   'Sun Chun'],
#   'director_name': 'Zhang Li',
#   'movie_title': '1911'},
#  {'actor_names': ['Lorraine Gary',
#                   'Murray Hamilton',
#                   'John Belushi',
#                   'Ned Beatty',
#                   'Dan Aykroyd'],
#   'director_name': 'Steven Spielberg',
#   'movie_title': '1941'},
#  {'actor_names': ['Oliver Platt',
#                   'John Cusack',
#                   'Thandie Newton',
#                   'Amanda Peet',
#                   'Chiwetel Ejiofor'],
#   'director_name': 'Roland Emmerich',
#   'movie_title': '2012'},
#  {'actor_names': ['Lena Headey',
#                   'David Wenham',
#                   'Sullivan Stapleton',
#                   'Eva Green',
#                   'Callan Mulvey'],
#   'director_name': 'Noam Murro',
#   'movie_title': '300: Rise of an Empire'},
#  {'actor_names': ['Russell Crowe',
#                   'Peter Fonda',
#                   'Christian Bale',
#                   'Logan Lerman',
#                   'Dallas Roberts'],
#   'director_name': 'James Mangold',
#   'movie_title': '3:10 to Yuma'},
#  {'actor_names': ['Keanu Reeves',
#                   'Hiroyuki Sanada',
#                   'Tadanobu Asano',
#                   'Kou Shibasaki',
#                   'Min Tanaka'],
#   'director_name': 'Carl Rinsch',
#   'movie_title': '47 Ronin'},
#  {'actor_names': ['Sean Connery',
#                   'James Caan',
#                   'Dirk Bogarde',
#                   'Michael Caine',
#                   'Edward Fox'],
#   'director_name': 'Richard Attenborough',
#   'movie_title': 'A Bridge Too Far'},
#  {'actor_names': ['Kevin Spacey',
#                   'Hayden Panettiere',
#                   'Julia Louis-Dreyfus',
#                   'Phyllis Diller',
#                   'Bonnie Hunt'],
#   'director_name': 'John Lasseter',
#   'movie_title': "A Bug's Life"},
#  {'actor_names': ['Kevin Spacey',
#                   'Hayden Panettiere',
#                   'Julia Louis-Dreyfus',
#                   'Phyllis Diller',
#                   'Bonnie Hunt'],
#   'director_name': 'Andrew Stanton',
#   'movie_title': "A Bug's Life"},
#  {'actor_names': ['David Hewlett',
#                   'Kate Hewlett',
#                   'Paul McGillion',
#                   'Christopher Judge',
#                   'Rachel Luttrell'],
#   'director_name': 'David Hewlett',
#   'movie_title': "A Dog's Breakfast"},
#  {'actor_names': ['Helen Hayes',
#                   'Gary Cooper',
#                   'Adolphe Menjou',
#                   'Mary Philips',
#                   'Jack La Rue'],
#   'director_name': 'Frank Borzage',
#   'movie_title': 'A Farewell to Arms'},
#  {'actor_names': ['Leonor Varela', 'Luke Perry', 'Anna Claire Sneed'],
#   'director_name': 'Jonathan Meyers',
#   'movie_title': 'A Fine Step'},
#  {'actor_names': ['Bruce Willis',
#                   'Mary Elizabeth Winstead',
#                   'Sebastian Koch',
#                   'Юлия Снигирь',
#                   'Jai Courtney'],
#   'director_name': 'John Moore',
#   'movie_title': 'A Good Day to Die Hard'},
#  {'actor_names': ['Tom Hanks',
#                   'Madonna',
#                   'Jon Lovitz',
#                   'Geena Davis',
#                   'Lori Petty'],
#   'director_name': 'Penny Marshall',
#   'movie_title': 'A League of Their Own'},
#  {'actor_names': ['Orson Welles',
#                   'Robert Shaw',
#                   'Paul Scofield',
#                   'Wendy Hiller',
#                   'Leo McKern'],
#   'director_name': 'Fred Zinnemann',
#   'movie_title': 'A Man for All Seasons'},
#  {'actor_names': ['Liam Neeson',
#                   'Charlize Theron',
#                   'Neil Patrick Harris',
#                   'Amanda Seyfried',
#                   'Seth MacFarlane'],
#   'director_name': 'Seth MacFarlane',
#   'movie_title': 'A Million Ways to Die in the West'},
#  {'actor_names': ['Lau Ching-Wan', 'Tang Wei', 'Qin Hailu', 'Jing Boran'],
#   'director_name': 'Mabel Cheung',
#   'movie_title': 'A Tale of Three Cities'},
#  {'actor_names': ['Melanie Griffith',
#                   'Tim Curry',
#                   'Gemma Arterton',
#                   'Yuri Lowenthal',
#                   'Isabelle Fuhrman'],
#   'director_name': 'Ben Stassen',
#   'movie_title': "A Turtle's Tale: Sammy's Adventures"},
#  {'actor_names': ['Jack Nicholson',
#                   'Dermot Mulroney',
#                   'Kathy Bates',
#                   'Hope Davis',
#                   'June Squibb'],
#   'director_name': 'Alexander Payne',
#   'movie_title': 'About Schmidt'},
#  {'actor_names': ['Simon Callow',
#                   'Jim Carrey',
#                   'Bob Gunton',
#                   'Ian McNeice',
#                   'Maynard Eziashi'],
#   'director_name': 'Steve Oedekerk',
#   'movie_title': 'Ace Ventura: When Nature Calls'},
#  {'actor_names': ['Evan Rachel Wood',
#                   'Jim Sturgess',
#                   'Joe Anderson',
#                   'Dana Fuchs',
#                   'Martin Luther'],
#   'director_name': 'Julie Taymor',
#   'movie_title': 'Across the Universe'},
#  {'actor_names': ['Willem Dafoe',
#                   'Derek Jacobi',
#                   'Jeff Goldblum',
#                   'Ayelet Zurer',
#                   'Hana Laslo'],
#   'director_name': 'Paul Schrader',
#   'movie_title': 'Adam Resurrected'},
#  {'actor_names': ['Maria Schrader',
#                   'Juliane Köhler',
#                   'Johanna Wokalek',
#                   'Heike Makatsch',
#                   'Elisabeth Degen'],
#   'director_name': 'Max Färberböck',
#   'movie_title': 'Aimee & Jaguar'},
#  {'actor_names': ['Lloyd Bridges',
#                   'Robert Hays',
#                   'Julie Hagerty',
#                   'Kareem Abdul-Jabbar',
#                   'Peter Graves'],
#   'director_name': 'Jerry Zucker',
#   'movie_title': 'Airplane!'},
#  {'actor_names': ['Lloyd Bridges',
#                   'Robert Hays',
#                   'Julie Hagerty',
#                   'Kareem Abdul-Jabbar',
#                   'Peter Graves'],
#   'director_name': 'Jim Abrahams',
#   'movie_title': 'Airplane!'},
#  {'actor_names': ['Lloyd Bridges',
#                   'Robert Hays',
#                   'Julie Hagerty',
#                   'Kareem Abdul-Jabbar',
#                   'Peter Graves'],
#   'director_name': 'David Zucker',
#   'movie_title': 'Airplane!'},
#  {'actor_names': ['Tyrone Power',
#                   'Alice Faye',
#                   'Don Ameche',
#                   'Ethel Merman',
#                   'Jack Haley'],
#   'director_name': 'Henry King',
#   'movie_title': "Alexander's Ragtime Band"},
#  {'actor_names': ['Tom Skerritt',
#                   'Sigourney Weaver',
#                   'Veronica Cartwright',
#                   'Harry Dean Stanton',
#                   'John Hurt'],
#   'director_name': 'Ridley Scott',
#   'movie_title': 'Alien'},
#  {'actor_names': ['John Ortiz',
#                   'Steven Pasquale',
#                   'Reiko Aylesworth',
#                   'Ariel Gade',
#                   'Sam Trammell'],
#   'director_name': 'Colin Strause',
#   'movie_title': 'Aliens vs Predator: Requiem'},
#  {'actor_names': ['John Ortiz',
#                   'Steven Pasquale',
#                   'Reiko Aylesworth',
#                   'Ariel Gade',
#                   'Sam Trammell'],
#   'director_name': 'Greg Strause',
#   'movie_title': 'Aliens vs Predator: Requiem'},
#  {'actor_names': ['Matt LeBlanc',
#                   'Eddie Izzard',
#                   'James Cosmo',
#                   'Nicolette Krebitz',
#                   'David Tristan Birkin'],
#   'director_name': 'Stefan Ruzowitzky',
#   'movie_title': "All The Queen's Men"},
#  {'actor_names': ['Sean Penn',
#                   'Kate Winslet',
#                   'James Gandolfini',
#                   'Jude Law',
#                   'Patricia Clarkson'],
#   'director_name': 'Steven Zaillian',
#   'movie_title': "All the King's Men"},
#  {'actor_names': ['Paul Sorvino',
#                   'Terrance Zdunich',
#                   'Marc Senter',
#                   'Emilie Autumn',
#                   'Nivek Ogre'],
#   'director_name': 'Darren Lynn Bousman',
#   'movie_title': "Alleluia! The Devil's Carnival"},
#  {'actor_names': ['Christian Slater',
#                   'Stephen Dorff',
#                   'Tara Reid',
#                   'Frank C. Turner',
#                   'Matthew Walker'],
#   'director_name': 'Uwe Boll',
#   'movie_title': 'Alone in the Dark'},
#  {'actor_names': ['Dennis Hopper',
#                   'Danny Glover',
#                   'Christina Ricci',
#                   'Hayden Panettiere',
#                   'Justin Long'],
#   'director_name': 'Ben Gluck',
#   'movie_title': 'Alpha and Omega'},
#  {'actor_names': ['Dennis Hopper',
#                   'Danny Glover',
#                   'Christina Ricci',
#                   'Hayden Panettiere',
#                   'Justin Long'],
#   'director_name': 'Anthony Bell',
#   'movie_title': 'Alpha and Omega'},
#  {'actor_names': ['Michael Dudikoff',
#                   'Steve James',
#                   'Larry Poindexter',
#                   'Gary Conway',
#                   'Jeff Celentano'],
#   'director_name': 'Sam Firstenberg',
#   'movie_title': 'American Ninja 2: The Confrontation'},
#  {'actor_names': ['Bradley Cooper',
#                   'Sienna Miller',
#                   'Kyle Gallner',
#                   'Cole Konis',
#                   'Ben Reed'],
#   'director_name': 'Clint Eastwood',
#   'movie_title': 'American Sniper'},
#  {'actor_names': ['Chris Cooper',
#                   'Yul Vazquez',
#                   'DJ Qualls',
#                   'Garret Dillahunt',
#                   'Lucas Neff'],
#   'director_name': 'John Sayles',
#   'movie_title': 'Amigo'},
#  {'actor_names': ['Billy West',
#                   'George H. W. Bush',
#                   'George W. Bush',
#                   'Al Gore',
#                   'Ronald Reagan'],
#   'director_name': 'Davis Guggenheim',
#   'movie_title': 'An Inconvenient Truth'},
#  {'actor_names': ['Johnny Messner',
#                   'KaDee Strickland',
#                   'Matthew Marsden',
#                   'Nicholas Gonzalez',
#                   'Eugene Byrd'],
#   'director_name': 'Dwight H. Little',
#   'movie_title': 'Anacondas: The Hunt for the Blood Orchid'},
#  {'actor_names': ['Christopher Lloyd',
#                   'Meg Ryan',
#                   'John Cusack',
#                   'Angela Lansbury',
#                   'Hank Azaria'],
#   'director_name': 'Don Bluth',
#   'movie_title': 'Anastasia'},
#  {'actor_names': ['Christopher Lloyd',
#                   'Meg Ryan',
#                   'John Cusack',
#                   'Angela Lansbury',
#                   'Hank Azaria'],
#   'director_name': 'Gary Goldman',
#   'movie_title': 'Anastasia'},
#  {'actor_names': ['Robert Carlyle',
#                   'Emily Watson',
#                   'Joe Breen',
#                   'Michael Legge',
#                   'Ciaran Owens'],
#   'director_name': 'Alan Parker',
#   'movie_title': "Angela's Ashes"},
#  {'actor_names': ['Megan Follows',
#                   'Colleen Dewhurst',
#                   'Richard Farnsworth',
#                   'Patricia Hamilton',
#                   'Marilyn Lightstone'],
#   'director_name': 'Kevin Sullivan',
#   'movie_title': 'Anne of Green Gables'},
#  {'actor_names': ['Edward Arnold',
#                   'Betty Hutton',
#                   'Howard Keel',
#                   'Louis Calhern',
#                   'J. Carrol Naish'],
#   'director_name': 'George Sidney',
#   'movie_title': 'Annie Get Your Gun'},
#  {'actor_names': ['Vanessa Redgrave',
#                   'David Thewlis',
#                   'Joely Richardson',
#                   'Rhys Ifans',
#                   'Jamie Campbell Bower'],
#   'director_name': 'Roland Emmerich',
#   'movie_title': 'Anonymous'},
#  {'actor_names': ['Marlon Brando',
#                   'Robert Duvall',
#                   'Frederic Forrest',
#                   'Martin Sheen',
#                   'Sam Bottoms'],
#   'director_name': 'Francis Ford Coppola',
#   'movie_title': 'Apocalypse Now'},
#  {'actor_names': ['Nicole Kidman',
#                   'Hugh Jackman',
#                   'David Wenham',
#                   'Essie Davis',
#                   'Bryan Brown'],
#   'director_name': 'Baz Luhrmann',
#   'movie_title': 'Australia'},
#  {'actor_names': ['Lena Olin',
#                   'Jessica Alba',
#                   'Terrence Howard',
#                   'Hayden Christensen',
#                   'Charlie Hewson'],
#   'director_name': 'Joby Harold',
#   'movie_title': 'Awake'},
#  {'actor_names': ['Rana Daggubati',
#                   'Prabhas',
#                   'Tamanna Bhatia',
#                   'Anushka Shetty',
#                   'Ramya Krishnan'],
#   'director_name': 'S.S. Rajamouli',
#   'movie_title': 'Baahubali: The Beginning'},
#  {'actor_names': ['Danny Glover',
#                   'Sam Elliott',
#                   'Courteney Cox',
#                   'Kevin James',
#                   'Wanda Sykes'],
#   'director_name': 'Steve Oedekerk',
#   'movie_title': 'Barnyard'},
#  {'actor_names': ["Ryan O'Neal",
#                   'Marisa Berenson',
#                   'Hardy Krüger',
#                   'Diana Körner',
#                   'Frank Middlemass'],
#   'director_name': 'Stanley Kubrick',
#   'movie_title': 'Barry Lyndon'},
#  {'actor_names': ['Pat Hingle',
#                   'Jack Nicholson',
#                   'Kim Basinger',
#                   'Michael Keaton',
#                   'Michael Gough'],
#   'director_name': 'Tim Burton',
#   'movie_title': 'Batman'},
#  {'actor_names': ['Tommy Lee Jones',
#                   'Val Kilmer',
#                   'Nicole Kidman',
#                   'Jim Carrey',
#                   "Chris O'Donnell"],
#   'director_name': 'Joel Schumacher',
#   'movie_title': 'Batman Forever'},
#  {'actor_names': ['Danny DeVito',
#                   'Christopher Walken',
#                   'Michelle Pfeiffer',
#                   'Michael Keaton',
#                   'Michael Gough'],
#   'director_name': 'Tim Burton',
#   'movie_title': 'Batman Returns'},
#  {'actor_names': ['Ben Affleck',
#                   'Amy Adams',
#                   'Jesse Eisenberg',
#                   'Henry Cavill',
#                   'Gal Gadot'],
#   'director_name': 'Zack Snyder',
#   'movie_title': 'Batman v Superman: Dawn of Justice'},
#  {'actor_names': ['Roddy McDowall',
#                   'Natalie Trundy',
#                   'Severn Darden',
#                   'Austin Stoker',
#                   'Claude Akins'],
#   'director_name': 'J. Lee Thompson',
#   'movie_title': 'Battle for the Planet of the Apes'},
#  {'actor_names': ['Sarah Douglas',
#                   'Marc Singer',
#                   'Kari Wuhrer',
#                   'Wings Hauser',
#                   'Robert Fieldsteel'],
#   'director_name': 'Sylvio Tabet',
#   'movie_title': 'Beastmaster 2: Through the Portal of Time'},
#  {'actor_names': ['Edward Furlong',
#                   'Michael Berryman',
#                   'Kristin Booth',
#                   'Michael Eisner',
#                   'Dee Hanna'],
#   'director_name': 'Justin Thomas Ostensen',
#   'movie_title': 'Below Zero'},
#  {'actor_names': ['Brendan Cowell',
#                   'Harrison Gilbertson',
#                   'Steve Le Marquand',
#                   'Gyton Grantley',
#                   'Alan Dukes'],
#   'director_name': 'Jeremy Sims',
#   'movie_title': 'Beneath Hill 60'},
#  {'actor_names': ['Anthony Hopkins',
#                   'Robin Wright',
#                   'John Malkovich',
#                   'Angelina Jolie',
#                   'Ray Winstone'],
#   'director_name': 'Robert Zemeckis',
#   'movie_title': 'Beowulf'},
#  {'actor_names': ['Angelina Jolie',
#                   'Noah Emmerich',
#                   'Teri Polo',
#                   'Linus Roache',
#                   'Clive Owen'],
#   'director_name': 'Martin Campbell',
#   'movie_title': 'Beyond Borders'},
#  {'actor_names': ['Albert Finney',
#                   'Jessica Lange',
#                   'Helena Bonham Carter',
#                   'Ewan McGregor',
#                   'Billy Crudup'],
#   'director_name': 'Tim Burton',
#   'movie_title': 'Big Fish'},
#  {'actor_names': ['Sebastian Koch',
#                   'Carice van Houten',
#                   'Thom Hoffman',
#                   'Halina Reijn',
#                   'Waldemar Kobus'],
#   'director_name': 'Paul Verhoeven',
#   'movie_title': 'Black Book'},
#  {'actor_names': ['Tom Sizemore',
#                   'Ewan McGregor',
#                   'William Fichtner',
#                   'Jason Isaacs',
#                   'Josh Hartnett'],
#   'director_name': 'Ridley Scott',
#   'movie_title': 'Black Hawk Down'},
#  {'actor_names': ['Mickey Rourke',
#                   'Kim Basinger',
#                   'Anne Heche',
#                   'Razaaq Adoti',
#                   'Sarah Wayne Callies'],
#   'director_name': 'Jeta Amata',
#   'movie_title': 'Black November'},
#  {'actor_names': ['Kate Capshaw',
#                   'Andy García',
#                   'Michael Douglas',
#                   'Shigeru Kôyama',
#                   'John Spencer'],
#   'director_name': 'Ridley Scott',
#   'movie_title': 'Black Rain'},
#  {'actor_names': ['Sarah Farooqui',
#                   'Chris Ivan Cevic',
#                   'Alex Petrovitch',
#                   'Michele Morrow',
#                   'Ivan L. Moody'],
#   'director_name': 'Christopher Hutson',
#   'movie_title': 'Bled'},
#  {'actor_names': ['Leonardo DiCaprio',
#                   'Djimon Hounsou',
#                   'Jennifer Connelly',
#                   'Arnold Vosloo',
#                   'Kagiso Kuypers'],
#   'director_name': 'Edward Zwick',
#   'movie_title': 'Blood Diamond'},
#  {'actor_names': ['Colm Feore',
#                   'Patrick Huard',
#                   'Michel Beaudry',
#                   'Patrice Bélanger',
#                   'Hugolin Chevrette-Landesque'],
#   'director_name': 'Erik Canuel',
#   'movie_title': 'Bon Cop Bad Cop'},
#  {'actor_names': ['Isabelle Adjani',
#                   'Gérard Depardieu',
#                   'Virginie Ledoyen',
#                   'Grégori Derangère',
#                   'Yvan Attal'],
#   'director_name': 'Jean-Paul Rappeneau',
#   'movie_title': 'Bon voyage'},
#  {'actor_names': ['Pamela Anderson',
#                   'Sacha Baron Cohen',
#                   'Ken Davitian',
#                   'Luenell',
#                   'Bob Barr'],
#   'director_name': 'Larry Charles',
#   'movie_title': 'Borat: Cultural Learnings of America for Make Benefit '
#                  'Glorious Nation of Kazakhstan'},
#  {'actor_names': ['Tom Cruise',
#                   'Raymond J. Barry',
#                   'Caroline Kava',
#                   'Holly Marie Combs',
#                   'Kyra Sedgwick'],
#   'director_name': 'Oliver Stone',
#   'movie_title': 'Born on the Fourth of July'},
#  {'actor_names': ['Mel Gibson',
#                   'Patrick McGoohan',
#                   'Catherine McCormack',
#                   'Sophie Marceau',
#                   'Angus Macfadyen'],
#   'director_name': 'Mel Gibson',
#   'movie_title': 'Braveheart'},
#  {'actor_names': ['Andrea Martin',
#                   'Peter Friedman',
#                   'Daryl Wein',
#                   'Zoe Lister-Jones',
#                   'Julie White'],
#   'director_name': 'Daryl Wein',
#   'movie_title': 'Breaking Upwards'},
#  {'actor_names': ['Alan Alda',
#                   'Tom Hanks',
#                   'Sebastian Koch',
#                   'Amy Ryan',
#                   'Mark Rylance'],
#   'director_name': 'Steven Spielberg',
#   'movie_title': 'Bridge of Spies'},
#  {'actor_names': ['John Travolta',
#                   'Delroy Lindo',
#                   'Christian Slater',
#                   'Samantha Mathis',
#                   'Bob Gunton'],
#   'director_name': 'John Woo',
#   'movie_title': 'Broken Arrow'},
#  {'actor_names': ["Vincent D'Onofrio",
#                   'Thomas Jane',
#                   'Sean Patrick Flanery',
#                   'Anton Yelchin',
#                   'María Valverde'],
#   'director_name': 'Vidhu Vinod Chopra',
#   'movie_title': 'Broken Horses'},
#  {'actor_names': ['Dianne Wiest',
#                   'Mary-Louise Parker',
#                   'John Cusack',
#                   'Jennifer Tilly',
#                   'Chazz Palminteri'],
#   'director_name': 'Woody Allen',
#   'movie_title': 'Bullets Over Broadway'},
#  {'actor_names': ['Tommy Lee Jones',
#                   'Hugo Weaving',
#                   'Chris Evans',
#                   'Sebastian Stan',
#                   'Hayley Atwell'],
#   'director_name': 'Joe Johnston',
#   'movie_title': 'Captain America: The First Avenger'},
#  {'actor_names': ['Mimi Rogers',
#                   'Leonor Varela',
#                   'Kate Mara',
#                   'David Oyelowo',
#                   'Michael Kenneth Williams'],
#   'director_name': 'Jerry Jameson',
#   'movie_title': 'Captive'},
#  {'actor_names': ['Will Ferrell',
#                   'Gael García Bernal',
#                   'Diego Luna',
#                   'Efren Ramirez',
#                   'Génesis Rodríguez'],
#   'director_name': 'Matt Piedmont',
#   'movie_title': 'Casa De Mi Padre'},
#  {'actor_names': ['Tom Hanks',
#                   'Helen Hunt',
#                   'Chris Noth',
#                   'Paul Sanchez',
#                   'Lari White'],
#   'director_name': 'Robert Zemeckis',
#   'movie_title': 'Cast Away'},
#  {'actor_names': ['Jennifer Beals',
#                   'Sam Robards',
#                   'Kristen Stewart',
#                   'Corbin Bleu',
#                   'Max Thieriot'],
#   'director_name': 'Bart Freundlich',
#   'movie_title': 'Catch That Kid'},
#  {'actor_names': ['Jennifer Beals',
#                   'Sam Robards',
#                   'Kristen Stewart',
#                   'Corbin Bleu',
#                   'Max Thieriot'],
#   'director_name': 'James Sbardellati',
#   'movie_title': 'Catch That Kid'},
#  {'actor_names': ['Jennifer Beals',
#                   'Sam Robards',
#                   'Kristen Stewart',
#                   'Corbin Bleu',
#                   'Max Thieriot'],
#   'director_name': 'Peter Merwin',
#   'movie_title': 'Catch That Kid'},
#  {'actor_names': ['Martin Balsam',
#                   'Jack Gilford',
#                   'Alan Arkin',
#                   'Richard Benjamin',
#                   'Art Garfunkel'],
#   'director_name': 'Mike Nichols',
#   'movie_title': 'Catch-22'},
#  {'actor_names': ['Bette Midler',
#                   'Nick Nolte',
#                   'Christina Applegate',
#                   'James Marsden',
#                   'Pascale Hutton'],
#   'director_name': 'Brad Peyton',
#   'movie_title': 'Cats & Dogs 2 : The Revenge of Kitty Galore'},
#  {'actor_names': ['Amos Oz'],
#   'director_name': 'Mor Loushy',
#   'movie_title': 'Censored Voices'},
#  {'actor_names': ['Keith David',
#                   'Brad Dourif',
#                   'Nikki Reed',
#                   'Betsy Russell',
#                   'Cherilyn Wilson'],
#   'director_name': 'Deon Taylor',
#   'movie_title': 'Chain Letter'},
#  {'actor_names': ['Robert Downey Jr.',
#                   'Hope Davis',
#                   'Anton Yelchin',
#                   'Tyler Hilton',
#                   'Kat Dennings'],
#   'director_name': 'Jon Poll',
#   'movie_title': 'Charlie Bartlett'},
#  {'actor_names': ['Donal Logue',
#                   'Zac Efron',
#                   'Charlie Tahan',
#                   'Amanda Crew',
#                   'Augustus Prew'],
#   'director_name': 'Burr Steers',
#   'movie_title': 'Charlie St. Cloud'},
#  {'actor_names': ['Tom Hanks',
#                   'Julia Roberts',
#                   'Philip Seymour Hoffman',
#                   'Om Puri',
#                   'Amy Adams'],
#   'director_name': 'Mike Nichols',
#   'movie_title': "Charlie Wilson's War"},
#  {'actor_names': ['John Forsythe',
#                   'Bill Murray',
#                   'Drew Barrymore',
#                   'Cameron Diaz',
#                   'Lucy Liu'],
#   'director_name': 'McG',
#   'movie_title': "Charlie's Angels"},
#  {'actor_names': ['Michelle Pfeiffer',
#                   'Kathy Bates',
#                   'Iben Hjejle',
#                   'Rupert Friend',
#                   'Felicity Jones'],
#   'director_name': 'Stephen Frears',
#   'movie_title': 'Cheri'},
#  {'actor_names': ['Jesse McCartney',
#                   'Jonathan Sadowski',
#                   'Olivia Taylor Dudley',
#                   'Ingrid Bolsø Berdal',
#                   'Alex Feldman'],
#   'director_name': 'Bradley Parker',
#   'movie_title': 'Chernobyl Diaries'},
#  {'actor_names': ['Liu Ye',
#                   'Gao Yuanyuan',
#                   'Hideo Nakaizumi',
#                   'John Paisley',
#                   'Beverly Peckous'],
#   'director_name': 'Lu Chuan',
#   'movie_title': 'City of Life and Death'},
#  {'actor_names': ['Liam Neeson',
#                   'Ralph Fiennes',
#                   'Jason Flemyng',
#                   'Gemma Arterton',
#                   'Sam Worthington'],
#   'director_name': 'Louis Leterrier',
#   'movie_title': 'Clash of the Titans'},
#  {'actor_names': ['Harrison Ford',
#                   'Anne Archer',
#                   'Willem Dafoe',
#                   'Joaquim de Almeida',
#                   'Henry Czerny'],
#   'director_name': 'Phillip Noyce',
#   'movie_title': 'Clear and Present Danger'},
#  {'actor_names': ['Christopher Walken',
#                   'Adam Sandler',
#                   'Kate Beckinsale',
#                   'Henry Winkler',
#                   'David Hasselhoff'],
#   'director_name': 'Frank Coraci',
#   'movie_title': 'Click'},
#  {'actor_names': ['Tom Hanks',
#                   'Halle Berry',
#                   'Hugo Weaving',
#                   'Jim Broadbent',
#                   'Jim Sturgess'],
#   'director_name': 'Lilly Wachowski',
#   'movie_title': 'Cloud Atlas'},
#  {'actor_names': ['Tom Hanks',
#                   'Halle Berry',
#                   'Hugo Weaving',
#                   'Jim Broadbent',
#                   'Jim Sturgess'],
#   'director_name': 'Lana Wachowski',
#   'movie_title': 'Cloud Atlas'},
#  {'actor_names': ['Tom Hanks',
#                   'Halle Berry',
#                   'Hugo Weaving',
#                   'Jim Broadbent',
#                   'Jim Sturgess'],
#   'director_name': 'Tom Tykwer',
#   'movie_title': 'Cloud Atlas'},
#  {'actor_names': ['Nicole Kidman',
#                   'Renée Zellweger',
#                   'Brendan Gleeson',
#                   'Jude Law',
#                   'Eileen Atkins'],
#   'director_name': 'Anthony Minghella',
#   'movie_title': 'Cold Mountain'},
#  {'actor_names': ['James Olson',
#                   'Rae Dawn Chong',
#                   'Vernon Wells',
#                   'Arnold Schwarzenegger',
#                   'Dan Hedaya'],
#   'director_name': 'Mark L. Lester',
#   'movie_title': 'Commando'},
#  {'actor_names': ['Max von Sydow',
#                   'Arnold Schwarzenegger',
#                   'James Earl Jones',
#                   'Sandahl Bergman',
#                   'Cassandra Gava'],
#   'director_name': 'John Milius',
#   'movie_title': 'Conan the Barbarian'},
#  {'actor_names': ['Arnold Schwarzenegger',
#                   'Tracey Walter',
#                   'Grace Jones',
#                   'Wilt Chamberlain',
#                   'Mako'],
#   'director_name': 'Richard Fleischer',
#   'movie_title': 'Conan the Destroyer'},
#  {'actor_names': ['Michael Moriarty',
#                   'Lou Diamond Phillips',
#                   'Denzel Washington',
#                   'Meg Ryan',
#                   'Matt Damon'],
#   'director_name': 'Edward Zwick',
#   'movie_title': 'Courage Under Fire'},
#  {'actor_names': ['Tommy Lee Jones',
#                   'Kevin Costner',
#                   'Gary Oldman',
#                   'Ryan Reynolds',
#                   'Jordi Mollà'],
#   'director_name': 'Ariel Vromen',
#   'movie_title': 'Criminal'},
#  {'actor_names': ['Michelle Yeoh',
#                   'Chow Yun-fat',
#                   'Zhang Ziyi',
#                   'Chang Chen',
#                   'Cheng Pei-Pei'],
#   'director_name': 'Ang Lee',
#   'movie_title': 'Crouching Tiger, Hidden Dragon'},
#  {'actor_names': ['Dick Van Dyke',
#                   'Drew Barrymore',
#                   'Eugene Levy',
#                   'David Cross',
#                   'Will Ferrell'],
#   'director_name': "Matthew O'Callaghan",
#   'movie_title': 'Curious George'},
#  {'actor_names': ['Jaime Pressly',
#                   'Devon Aoki',
#                   'Holly Valance',
#                   'Sarah Carter',
#                   'Natassia Malthe'],
#   'director_name': 'Corey Yuen Kwai',
#   'movie_title': 'DOA: Dead or Alive'},
#  {'actor_names': ['Dominique Sanda',
#                   'Jan-Michael Vincent',
#                   'George Peppard',
#                   'Paul Winfield',
#                   'Jackie Earle Haley'],
#   'director_name': 'Jack Smight',
#   'movie_title': 'Damnation Alley'},
#  {'actor_names': ['Kevin Costner',
#                   'Mary McDonnell',
#                   'Graham Greene',
#                   'Rodney A. Grant',
#                   'Floyd Red Crow Westerman'],
#   'director_name': 'Kevin Costner',
#   'movie_title': 'Dances with Wolves'},
#  {'actor_names': ['Julie Andrews',
#                   'Rock Hudson',
#                   'Jeremy Kemp',
#                   'Lance Percival',
#                   'Michael Witney'],
#   'director_name': 'Blake Edwards',
#   'movie_title': 'Darling Lili'},
#  {'actor_names': ['Jürgen Prochnow',
#                   'Herbert Grönemeyer',
#                   'Klaus Wennemann',
#                   'Hubertus Bengsch',
#                   'Martin Semmelrogge'],
#   'director_name': 'Wolfgang Petersen',
#   'movie_title': 'Das Boot'},
#  {'actor_names': ['Robert J. Wilke',
#                   'Richard Gere',
#                   'Brooke Adams',
#                   'Linda Manz',
#                   'Sam Shepard'],
#   'director_name': 'Terrence Malick',
#   'movie_title': 'Days of Heaven'},
#  {'actor_names': ['Robert Duvall',
#                   'Vanessa Redgrave',
#                   'Morgan Freeman',
#                   'Elijah Wood',
#                   'Téa Leoni'],
#   'director_name': 'Mimi Leder',
#   'movie_title': 'Deep Impact'},
#  {'actor_names': ['Lenore Zann',
#                   'Maury Chaykin',
#                   'Kate Lynch',
#                   'Kevin King',
#                   'John Walsch'],
#   'director_name': 'Paul Donovan',
#   'movie_title': 'Def-Con 4'},
#  {'actor_names': ['Lenore Zann',
#                   'Maury Chaykin',
#                   'Kate Lynch',
#                   'Kevin King',
#                   'John Walsch'],
#   'director_name': 'Digby Cook',
#   'movie_title': 'Def-Con 4'},
#  {'actor_names': ['Anne Bancroft',
#                   'Val Kilmer',
#                   'Jennifer Love Hewitt',
#                   'Freddie Prinze Jr.',
#                   'Chris Kattan'],
#   'director_name': 'Marc F. Adler',
#   'movie_title': 'Delgo'},
#  {'actor_names': ['Anne Bancroft',
#                   'Val Kilmer',
#                   'Jennifer Love Hewitt',
#                   'Freddie Prinze Jr.',
#                   'Chris Kattan'],
#   'director_name': 'Jason Maurer',
#   'movie_title': 'Delgo'},
#  {'actor_names': ['Vince Vaughn',
#                   'Cobie Smulders',
#                   'Chris Pratt',
#                   'Britt Robertson',
#                   'Jack Reynor'],
#   'director_name': 'Ken Scott',
#   'movie_title': 'Delivery Man'},
#  {'actor_names': ['Steve Buscemi',
#                   'Antonio Banderas',
#                   'Joaquim de Almeida',
#                   'Salma Hayek',
#                   'Cheech Marin'],
#   'director_name': 'Robert Rodriguez',
#   'movie_title': 'Desperado'},
#  {'actor_names': ['Fairuza Balk',
#                   'Stephen Dorff',
#                   'Norman Reedus',
#                   'Brad Renfro',
#                   'Max Perlich'],
#   'director_name': 'Scott Kalvert',
#   'movie_title': 'Deuces Wild'},
#  {'actor_names': ['Al Pacino',
#                   'Warren Beatty',
#                   'Madonna',
#                   'Charlie Korsmo',
#                   'Glenne Headly'],
#   'director_name': 'Warren Beatty',
#   'movie_title': 'Dick Tracy'},
#  {'actor_names': ['Pierce Brosnan',
#                   'Halle Berry',
#                   'Rick Yune',
#                   'Rosamund Pike',
#                   'Toby Stephens'],
#   'director_name': 'Lee Tamahori',
#   'movie_title': 'Die Another Day'},
#  {'actor_names': ['Paul Rudd',
#                   'Zach Galifianakis',
#                   'Steve Carell',
#                   'Stephanie Szostak',
#                   'Jemaine Clement'],
#   'director_name': 'Jay Roach',
#   'movie_title': 'Dinner for Schmucks'},
#  {'actor_names': ['Jason Mewes',
#                   'Linda Fiorentino',
#                   'Ben Affleck',
#                   'Matt Damon',
#                   'Chris Rock'],
#   'director_name': 'Kevin Smith',
#   'movie_title': 'Dogma'},
#  {'actor_names': ['George C. Scott',
#                   'Peter Sellers',
#                   'Sterling Hayden',
#                   'Keenan Wynn',
#                   'Slim Pickens'],
#   'director_name': 'Stanley Kubrick',
#   'movie_title': 'Dr. Strangelove or: How I Learned to Stop Worrying and Love '
#                  'the Bomb'},
#  {'actor_names': ['Carrie-Anne Moss',
#                   'Lucas Grabeel',
#                   'Blythe Auffarth',
#                   'Charlie Schlatter',
#                   'Simon Jaglom'],
#   'director_name': 'Yuefeng Song',
#   'movie_title': "Dragon Nest: Warriors' Dawn"},
#  {'actor_names': ['Chow Yun-fat',
#                   'Emmy Rossum',
#                   'Justin Chatwin',
#                   'Joon Park',
#                   'Jamie Chung'],
#   'director_name': 'James Wong',
#   'movie_title': 'Dragonball Evolution'},
#  {'actor_names': ['Lionel Barrymore',
#                   'Gregory Peck',
#                   'Jennifer Jones',
#                   'Joseph Cotten',
#                   'Herbert Marshall'],
#   'director_name': 'King Vidor',
#   'movie_title': 'Duel in the Sun'},
#  {'actor_names': ['Francesca Annis',
#                   'Kyle MacLachlan',
#                   'Leonardo Cimino',
#                   'Brad Dourif',
#                   'José Ferrer'],
#   'director_name': 'David Lynch',
#   'movie_title': 'Dune'},
#  {'actor_names': ['Christopher Walken',
#                   'Hugh Jackman',
#                   'Taron Egerton',
#                   'Ania Sowinski',
#                   'Mads Sjøgård Pettersen'],
#   'director_name': 'Dexter Fletcher',
#   'movie_title': 'Eddie the Eagle'},
#  {'actor_names': ['Alan Arkin',
#                   'Anthony Michael Hall',
#                   'Dianne Wiest',
#                   'Winona Ryder',
#                   'Johnny Depp'],
#   'director_name': 'Tim Burton',
#   'movie_title': 'Edward Scissorhands'},
#  {'actor_names': ['Terence Stamp',
#                   'Cary-Hiroyuki Tagawa',
#                   'Goran Visnjic',
#                   'Jennifer Garner',
#                   'Will Yun Lee'],
#   'director_name': 'Rob Bowman',
#   'movie_title': 'Elektra'},
#  {'actor_names': ['Harrison Ford',
#                   'Ben Kingsley',
#                   'Abigail Breslin',
#                   'Asa Butterfield',
#                   'Hailee Steinfeld'],
#   'director_name': 'Gavin Hood',
#   'movie_title': "Ender's Game"},
#  {'actor_names': ['Ed Harris',
#                   'Bob Hoskins',
#                   'Rachel Weisz',
#                   'Jude Law',
#                   'Joseph Fiennes'],
#   'director_name': 'Jean-Jacques Annaud',
#   'movie_title': 'Enemy at the Gates'},
#  {'actor_names': ['Sara Paxton',
#                   'Shaun Sipos',
#                   'Christopher Denham',
#                   'Scott Eastwood',
#                   'Katherine Waterston'],
#   'director_name': 'Jack Heller',
#   'movie_title': 'Enter Nowhere'},
#  {'actor_names': ['Jennifer Coolidge',
#                   'Kal Penn',
#                   'Jayma Mays',
#                   'Adam Campbell',
#                   'Faune A. Chambers'],
#   'director_name': 'Jason Friedberg',
#   'movie_title': 'Epic Movie'},
#  {'actor_names': ['Jennifer Coolidge',
#                   'Kal Penn',
#                   'Jayma Mays',
#                   'Adam Campbell',
#                   'Faune A. Chambers'],
#   'director_name': 'Aaron Seltzer',
#   'movie_title': 'Epic Movie'},
#  {'actor_names': ['Robert De Niro',
#                   'Drew Barrymore',
#                   'Kate Beckinsale',
#                   'Sam Rockwell',
#                   'Melissa Leo'],
#   'director_name': 'Kirk Jones',
#   'movie_title': "Everybody's Fine"},
#  {'actor_names': ['Izabella Scorupco',
#                   'Stellan Skarsgård',
#                   "James D'Arcy",
#                   'Julian Wadham',
#                   'Remy Sweeney'],
#   'director_name': 'Renny Harlin',
#   'movie_title': 'Exorcist: The Beginning'},
#  {'actor_names': ['Guy Pearce',
#                   'Mena Suvari',
#                   'Hayden Christensen',
#                   'Jimmy Fallon',
#                   'Sienna Miller'],
#   'director_name': 'George Hickenlooper',
#   'movie_title': 'Factory Girl'},
#  {'actor_names': ['Robert De Niro',
#                   'Michael Moore',
#                   'Ben Affleck',
#                   'George W. Bush',
#                   'Stevie Wonder'],
#   'director_name': 'Michael Moore',
#   'movie_title': 'Fahrenheit 9/11'},
#  {'actor_names': ['Viggo Mortensen',
#                   'Reda Kateb',
#                   'Djemel Barek',
#                   'Vincent Martin',
#                   'Nicolas Giraud'],
#   'director_name': 'David Oelhoffen',
#   'movie_title': 'Far from Men'},
#  {'actor_names': ['Marcell Nagy',
#                   'Béla Dóra',
#                   'Bálint Péntek',
#                   'Áron Dimény',
#                   'Péter Fancsikai'],
#   'director_name': 'Lajos Koltai',
#   'movie_title': 'Fateless'},
#  {'actor_names': ['Bob Hoskins',
#                   'Elaine Cassidy',
#                   'Arsinée Khanjian',
#                   'Peter McDonald',
#                   'Gerard McSorley'],
#   'director_name': 'Atom Egoyan',
#   'movie_title': "Felicia's Journey"},
#  {'actor_names': ['Chaim Topol',
#                   'Norma Crane',
#                   'Leonard Frey',
#                   'Molly Picon',
#                   'Paul Mann'],
#   'director_name': 'Norman Jewison',
#   'movie_title': 'Fiddler on the Roof'},
#  {'actor_names': ['Helena Bonham Carter',
#                   'Brad Pitt',
#                   'Edward Norton',
#                   'Jared Leto',
#                   'Meat Loaf'],
#   'director_name': 'David Fincher',
#   'movie_title': 'Fight Club'},
#  {'actor_names': ['Clint Eastwood',
#                   'David Huffman',
#                   'Ronald Lacey',
#                   'Freddie Jones',
#                   'Warren Clarke'],
#   'director_name': 'Clint Eastwood',
#   'movie_title': 'Firefox'},
#  {'actor_names': ['Sean Connery',
#                   'Richard Gere',
#                   'Ben Cross',
#                   'Julia Ormond',
#                   'Liam Cunningham'],
#   'director_name': 'Jerry Zucker',
#   'movie_title': 'First Knight'},
#  {'actor_names': ['Mads Mikkelsen',
#                   'Thure Lindhardt',
#                   'Stine Stengade',
#                   'Peter Mygind',
#                   'Mille Lehfeldt'],
#   'director_name': 'Ole Christian Madsen',
#   'movie_title': 'Flame & Citron'},
#  {'actor_names': ['Alan Alda',
#                   'Greg Kinnear',
#                   'Lauren Graham',
#                   'Aaron Abrams',
#                   'Tatiana Maslany'],
#   'director_name': 'Marc Abraham',
#   'movie_title': 'Flash of Genius'},
#  {'actor_names': ['Denzel Washington',
#                   'John Goodman',
#                   'Bruce Greenwood',
#                   'Don Cheadle',
#                   'Kelly Reilly'],
#   'director_name': 'Robert Zemeckis',
#   'movie_title': 'Flight'},
#  {'actor_names': ['Danny Glover',
#                   'Willem Dafoe',
#                   'Brad Johnson',
#                   'Rosanna Arquette',
#                   'Tom Sizemore'],
#   'director_name': 'John Milius',
#   'movie_title': 'Flight of the Intruder'},
#  {'actor_names': ['Jean Reno',
#                   'James Franco',
#                   'David Ellison',
#                   'Philip Winchester',
#                   'Abdul Salis'],
#   'director_name': 'Tony Bill',
#   'movie_title': 'Flyboys'},
#  {'actor_names': ["Peter O'Toole",
#                   'Andy García',
#                   'Rubén Blades',
#                   'Eva Longoria',
#                   'Oscar Isaac'],
#   'director_name': 'Dean Wright',
#   'movie_title': 'For Greater Glory - The True Story of Cristiada'},
#  {'actor_names': ["Catherine O'Hara",
#                   'Parker Posey',
#                   'John Michael Higgins',
#                   'Harry Shearer',
#                   'Christopher Moynihan'],
#   'director_name': 'Christopher Guest',
#   'movie_title': 'For Your Consideration'},
#  {'actor_names': ['Eric Stoltz',
#                   'Kate Connor',
#                   'Lyndsy Fonseca',
#                   'Andy Hirsch',
#                   'Camryn Manheim'],
#   'director_name': 'Michael Worth',
#   'movie_title': 'Fort McCoy'},
#  {'actor_names': ['Eric Stoltz',
#                   'Kate Connor',
#                   'Lyndsy Fonseca',
#                   'Andy Hirsch',
#                   'Camryn Manheim'],
#   'director_name': 'Kate Connor',
#   'movie_title': 'Fort McCoy'},
#  {'actor_names': ['George Takei',
#                   'Woody Harrelson',
#                   'Owen Wilson',
#                   'Colm Meaney',
#                   'Amy Poehler'],
#   'director_name': 'Jimmy Hayward',
#   'movie_title': 'Free Birds'},
#  {'actor_names': ['Cuba Gooding Jr.',
#                   'William Sadler',
#                   'David Rasche',
#                   'Sharon Leal',
#                   'Diane Salinger'],
#   'director_name': 'Peter Cousens',
#   'movie_title': 'Freedom'},
#  {'actor_names': ['Amy Steel',
#                   'John Furey',
#                   'Adrienne King',
#                   'Kirsten Baker',
#                   'Betsy Palmer'],
#   'director_name': 'Steve Miner',
#   'movie_title': 'Friday the 13th Part 2'},
#  {'actor_names': ['Clu Gulager',
#                   'Vincent Price',
#                   'Terry Kiser',
#                   'Rosalind Cash',
#                   'Cameron Mitchell'],
#   'director_name': 'Jeff Burr',
#   'movie_title': 'From a Whisper to a Scream'},
#  {'actor_names': ['George W. Bush',
#                   'Joshua Tickell',
#                   'Barbara Boxer',
#                   'Richard Branson',
#                   'Sheryl Crow'],
#   'director_name': 'Joshua Tickell',
#   'movie_title': 'Fuel'},
#  {'actor_names': ['Brad Pitt',
#                   'Logan Lerman',
#                   'Shia LaBeouf',
#                   'Michael Peña',
#                   'Jon Bernthal'],
#   'director_name': 'David Ayer',
#   'movie_title': 'Fury'},
#  {'actor_names': ['Alan Arkin',
#                   'Terence Stamp',
#                   'Dwayne Johnson',
#                   'Anne Hathaway',
#                   'Steve Carell'],
#   'director_name': 'Peter Segal',
#   'movie_title': 'Get Smart'},
#  {'actor_names': ['Gabriel Byrne',
#                   'Isaiah Washington',
#                   'Ron Eldard',
#                   'Julianna Margulies',
#                   'Desmond Harrington'],
#   'director_name': 'Steve Beck',
#   'movie_title': 'Ghost Ship'},
#  {'actor_names': ['Katie Peterson',
#                   'Shea Stewart',
#                   'Brandy Whitford',
#                   'Caley Hayes',
#                   'Ryan Keely'],
#   'director_name': 'Michael Hoffman Jr.',
#   'movie_title': 'Girls Gone Dead'},
#  {'actor_names': ['Katie Peterson',
#                   'Shea Stewart',
#                   'Brandy Whitford',
#                   'Caley Hayes',
#                   'Ryan Keely'],
#   'director_name': 'Aaron T. Wells',
#   'movie_title': 'Girls Gone Dead'},
#  {'actor_names': ['Tippi Hedren',
#                   'Robert Davi',
#                   'Alison Eastwood',
#                   'Katie Cleary',
#                   'Carole Davis'],
#   'director_name': 'Kristin Rizzo',
#   'movie_title': 'Give Me Shelter'},
#  {'actor_names': ['Matthew Broderick',
#                   'Cary Elwes',
#                   'Denzel Washington',
#                   'Morgan Freeman',
#                   'Jihmi Kennedy'],
#   'director_name': 'Edward Zwick',
#   'movie_title': 'Glory'},
#  {'actor_names': ['Robert Duvall',
#                   'C. Thomas Howell',
#                   'Jeff Daniels',
#                   'Stephen Lang',
#                   'Kevin Conway'],
#   'director_name': 'Ronald F. Maxwell',
#   'movie_title': 'Gods and Generals'},
#  {'actor_names': ['Clark Gable',
#                   'Olivia de Havilland',
#                   'Vivien Leigh',
#                   'Thomas Mitchell',
#                   'Leslie Howard'],
#   'director_name': 'Victor Fleming',
#   'movie_title': 'Gone with the Wind'},
#  {'actor_names': ['Ethan Hawke',
#                   'Bruce Greenwood',
#                   'January Jones',
#                   'Jake Abel',
#                   'Zoë Kravitz'],
#   'director_name': 'Andrew Niccol',
#   'movie_title': 'Good Kill'},
#  {'actor_names': ['Forest Whitaker',
#                   'Robin Williams',
#                   'Tung Thanh Tran',
#                   'Chintara Sukapatana',
#                   'Bruno Kirby'],
#   'director_name': 'Barry Levinson',
#   'movie_title': 'Good Morning, Vietnam'},
#  {'actor_names': ['Jeff Daniels',
#                   'David Strathairn',
#                   'Alex Borstein',
#                   'Rose Abdoo',
#                   'Dianne Reeves'],
#   'director_name': 'George Clooney',
#   'movie_title': 'Good Night, and Good Luck.'},
#  {'actor_names': ['Jack Black',
#                   'Amy Ryan',
#                   'Odeya Rush',
#                   'Dylan Minnette',
#                   'Jillian Bell'],
#   'director_name': 'Rob Letterman',
#   'movie_title': 'Goosebumps'},
#  {'actor_names': ['Clint Eastwood',
#                   'Brian Haley',
#                   'Christopher Carley',
#                   'Bee Vang',
#                   'Ahney Her'],
#   'director_name': 'Clint Eastwood',
#   'movie_title': 'Gran Torino'},
#  {'actor_names': ['Tim Robbins',
#                   'Peter Sarsgaard',
#                   'Ryan Reynolds',
#                   'Blake Lively',
#                   'Mark Strong'],
#   'director_name': 'Martin Campbell',
#   'movie_title': 'Green Lantern'},
#  {'actor_names': ['Matt Damon',
#                   'Brendan Gleeson',
#                   'Greg Kinnear',
#                   'Jason Isaacs',
#                   'Amy Ryan'],
#   'director_name': 'Paul Greengrass',
#   'movie_title': 'Green Zone'},
#  {'actor_names': ['Julie Christie',
#                   'Kenneth Branagh',
#                   'Derek Jacobi',
#                   'Richard Briers',
#                   'Kate Winslet'],
#   'director_name': 'Kenneth Branagh',
#   'movie_title': 'Hamlet'},
#  {'actor_names': ['Diane Keaton',
#                   'Walter Matthau',
#                   'Meg Ryan',
#                   'Lisa Kudrow',
#                   'Adam Arkin'],
#   'director_name': 'Diane Keaton',
#   'movie_title': 'Hanging Up'},
#  {'actor_names': ['Miley Cyrus',
#                   'Billy Ray Cyrus',
#                   'Emily Osment',
#                   'Jason Earles',
#                   'Taylor Swift'],
#   'director_name': 'Peter Chelsom',
#   'movie_title': 'Hannah Montana: The Movie'},
# ...
#                   'Eugene Roche',
#                   'Ron Morgan',
#                   'Emily Newman',
#                   'Paul Malevich'],
#   'director_name': 'Robinson Devor',
#   'movie_title': 'The Woman Chaser'},
#  {'actor_names': ['William Hurt',
#                   'Maria Bello',
#                   'Kristen Stewart',
#                   'Eddie Redmayne',
#                   'Veronica Russell'],
#   'director_name': 'Udayan Prasad',
#   'movie_title': 'The Yellow Handkerchief'},
#  {'actor_names': ['Miranda Richardson',
#                   'Jim Broadbent',
#                   'Paul Bettany',
#                   'Emily Blunt',
#                   'Mark Strong'],
#   'director_name': 'Jean-Marc Vallée',
#   'movie_title': 'The Young Victoria'},
#  {'actor_names': ['Judy Davis',
#                   'Helena Bonham Carter',
#                   'Callum Keith Rennie',
#                   'Kyle Catlett',
#                   'Niamh Wilson'],
#   'director_name': 'Jean-Pierre Jeunet',
#   'movie_title': 'The Young and Prodigious T.S. Spivet'},
#  {'actor_names': ['Dougray Scott',
#                   'Wes Bentley',
#                   'Jordi Mollà',
#                   'Charlie Cox',
#                   'Rodrigo Santoro'],
#   'director_name': 'Roland Joffé',
#   'movie_title': 'There Be Dragons'},
#  {'actor_names': ['Aliou Touré',
#                   'Oumar Touré',
#                   'Garba Touré',
#                   'Nathanael Dembélé',
#                   'Khaira Arby'],
#   'director_name': 'Johanna Schwartz',
#   'movie_title': 'They Will Have to Kill Us First'},
#  {'actor_names': ['Anthony Hopkins',
#                   'Stellan Skarsgård',
#                   'Natalie Portman',
#                   'Chris Hemsworth',
#                   'Tom Hiddleston'],
#   'director_name': 'Kenneth Branagh',
#   'movie_title': 'Thor'},
#  {'actor_names': ['Ice Cube',
#                   'Cliff Curtis',
#                   'Mark Wahlberg',
#                   'George Clooney',
#                   'Spike Jonze'],
#   'director_name': 'David O. Russell',
#   'movie_title': 'Three Kings'},
#  {'actor_names': ['Sean Connery',
#                   'John Cleese',
#                   'Ian Holm',
#                   'Shelley Duvall',
#                   'Michael Palin'],
#   'director_name': 'Terry Gilliam',
#   'movie_title': 'Time Bandits'},
#  {'actor_names': ['Oscar Isaac',
#                   'Michael Pollan',
#                   'Jane Goodall',
#                   'Jerry Brown',
#                   'Neal Barnard'],
#   'director_name': 'Charles Ferguson',
#   'movie_title': 'Time to Choose'},
#  {'actor_names': ['Corbin Bleu',
#                   'Chad Michael Murray',
#                   'Kat Dennings',
#                   'Rupert Friend',
#                   'Mark Saul'],
#   'director_name': 'Nathan Frankowski',
#   'movie_title': 'To Write Love on Her Arms'},
#  {'actor_names': ['Karin Dor',
#                   'Frederick Stafford',
#                   'Dany Robin',
#                   'Claude Jade',
#                   'Michel Subor'],
#   'director_name': 'Alfred Hitchcock',
#   'movie_title': 'Topaz'},
#  {'actor_names': ['Joseph Cotten',
#                   'Martin Balsam',
#                   'E.G. Marshall',
#                   'Sô Yamamura',
#                   'Tatsuya Mihashi'],
#   'director_name': 'Richard Fleischer',
#   'movie_title': 'Tora! Tora! Tora!'},
#  {'actor_names': ['Joseph Cotten',
#                   'Martin Balsam',
#                   'E.G. Marshall',
#                   'Sô Yamamura',
#                   'Tatsuya Mihashi'],
#   'director_name': 'Kinji Fukasaku',
#   'movie_title': 'Tora! Tora! Tora!'},
#  {'actor_names': ['Joseph Cotten',
#                   'Martin Balsam',
#                   'E.G. Marshall',
#                   'Sô Yamamura',
#                   'Tatsuya Mihashi'],
#   'director_name': 'Toshio Masuda',
#   'movie_title': 'Tora! Tora! Tora!'},
#  {'actor_names': ['Temuera Morrison',
#                   'Ray Winstone',
#                   'Andy Anderson',
#                   'Gareth Reeves',
#                   'Mark Mitchinson'],
#   'director_name': 'Ian Sharp',
#   'movie_title': 'Tracker'},
#  {'actor_names': ['Michael Douglas',
#                   'Benicio del Toro',
#                   'Jacob Vargas',
#                   'Tomás Milián',
#                   'Russell G. Jones'],
#   'director_name': 'Steven Soderbergh',
#   'movie_title': 'Traffic'},
#  {'actor_names': ['Morgan Freeman',
#                   'Johnny Depp',
#                   'Paul Bettany',
#                   'Kate Mara',
#                   'Rebecca Hall'],
#   'director_name': 'Wally Pfister',
#   'movie_title': 'Transcendence'},
#  {'actor_names': ['Tyrese Gibson',
#                   'Shia LaBeouf',
#                   'Josh Duhamel',
#                   'Megan Fox',
#                   'Rainn Wilson'],
#   'director_name': 'Michael Bay',
#   'movie_title': 'Transformers: Revenge of the Fallen'},
#  {'actor_names': ['Presley Chweneyagae',
#                   'Jerry Mofokeng',
#                   'Terry Pheto',
#                   'Kenneth Nkosi',
#                   'Zenzo Ngqobe'],
#   'director_name': 'Gavin Hood',
#   'movie_title': 'Tsotsi'},
#  {'actor_names': ['Sissy Spacek',
#                   'William Hurt',
#                   'Jonathan Jackson',
#                   'Alexis Bledel',
#                   'Scott Bairstow'],
#   'director_name': 'Jay Russell',
#   'movie_title': 'Tuck Everlasting'},
#  {'actor_names': ['Peter Facinelli',
#                   'Kristen Stewart',
#                   'Taylor Lautner',
#                   'Billy Burke',
#                   'Robert Pattinson'],
#   'director_name': 'Catherine Hardwicke',
#   'movie_title': 'Twilight'},
#  {'actor_names': ['Harvey Keitel',
#                   'David Keith',
#                   'Bill Paxton',
#                   'Matthew McConaughey',
#                   'Jon Bon Jovi'],
#   'director_name': 'Jonathan Mostow',
#   'movie_title': 'U-571'},
#  {'actor_names': ['Milla Jovovich',
#                   'Nick Chinlund',
#                   'Cameron Bright',
#                   'Sebastien Andrieu',
#                   'Ida Martin'],
#   'director_name': 'Kurt Wimmer',
#   'movie_title': 'Ultraviolet'},
#  {'actor_names': ['Garrett Hedlund',
#                   "Jack O'Connell",
#                   'Domhnall Gleeson',
#                   'Miyavi',
#                   'Finn Wittrock'],
#   'director_name': 'Angelina Jolie',
#   'movie_title': 'Unbroken'},
#  {'actor_names': ['Carrie Fisher',
#                   'Chevy Chase',
#                   'Eve Arden',
#                   'Joseph Maher',
#                   'Robert Donner'],
#   'director_name': 'Steve Rash',
#   'movie_title': 'Under the Rainbow'},
#  {'actor_names': ['Denise Richards',
#                   'Chi McBride',
#                   'Chris Kattan',
#                   'Eddie Griffin',
#                   'Aunjanue Ellis'],
#   'director_name': 'Malcolm D. Lee',
#   'movie_title': 'Undercover Brother'},
#  {'actor_names': ['Kate Beckinsale',
#                   'Scott Speedman',
#                   'Bill Nighy',
#                   'Michael Sheen',
#                   'Shane Brolly'],
#   'director_name': 'Len Wiseman',
#   'movie_title': 'Underworld'},
#  {'actor_names': ['Derek Jacobi',
#                   'Kate Beckinsale',
#                   'Scott Speedman',
#                   'Shane Brolly',
#                   'Tony Curran'],
#   'director_name': 'Len Wiseman',
#   'movie_title': 'Underworld: Evolution'},
#  {'actor_names': ['Richard Gere',
#                   'Diane Lane',
#                   'Olivier Martinez',
#                   'Zeljko Ivanek',
#                   'Erik Per Sullivan'],
#   'director_name': 'Adrian Lyne',
#   'movie_title': 'Unfaithful'},
#  {'actor_names': ['Jean-Claude Van Damme',
#                   'Michael Jai White',
#                   'Kiana Tom',
#                   'Bill Goldberg',
#                   'Heidi Schanz'],
#   'director_name': 'Mic Rodgers',
#   'movie_title': 'Universal Soldier: The Return'},
#  {'actor_names': ['Robert Redford',
#                   'Stockard Channing',
#                   'Michelle Pfeiffer',
#                   'Kate Nelligan',
#                   'Joe Mantegna'],
#   'director_name': 'Jon Avnet',
#   'movie_title': 'Up Close & Personal'},
#  {'actor_names': ['Hart Bochner',
#                   'Loretta Devine',
#                   'Anthony Anderson',
#                   'Jennifer Morrison',
#                   'Matthew Davis'],
#   'director_name': 'John Ottman',
#   'movie_title': 'Urban Legends: Final Cut'},
#  {'actor_names': ['John Hurt',
#                   'Stephen Rea',
#                   'Hugo Weaving',
#                   'Natalie Portman',
#                   'Stephen Fry'],
#   'director_name': 'James McTeigue',
#   'movie_title': 'V for Vendetta'},
#  {'actor_names': ['Tim Curry',
#                   'Jim Broadbent',
#                   'Ewan McGregor',
#                   'Hugh Laurie',
#                   'Ricky Gervais'],
#   'director_name': 'Gary Chapman',
#   'movie_title': 'Valiant'},
#  {'actor_names': ['Tom Cruise',
#                   'Terence Stamp',
#                   'Kenneth Branagh',
#                   'Bill Nighy',
#                   'Carice van Houten'],
#   'director_name': 'Bryan Singer',
#   'movie_title': 'Valkyrie'},
#  {'actor_names': ['Kurt Russell',
#                   'Tom Cruise',
#                   'Cameron Diaz',
#                   'Jason Lee',
#                   'Penélope Cruz'],
#   'director_name': 'Cameron Crowe',
#   'movie_title': 'Vanilla Sky'},
#  {'actor_names': ['Scarlett Johansson',
#                   'Penélope Cruz',
#                   'Javier Bardem',
#                   'Rebecca Hall',
#                   'Christopher Evan Welch'],
#   'director_name': 'Woody Allen',
#   'movie_title': 'Vicky Cristina Barcelona'},
#  {'actor_names': ['Dustin Hoffman',
#                   'Robert De Niro',
#                   'Jim Belushi',
#                   'Woody Harrelson',
#                   'Anne Heche'],
#   'director_name': 'Barry Levinson',
#   'movie_title': 'Wag the Dog'},
#  {'actor_names': ['Ari Folman', 'Ron Ben-Yishai', 'Dror Harazi', 'Ronny Dayag'],
#   'director_name': 'Ari Folman',
#   'movie_title': 'Waltz with Bashir'},
#  {'actor_names': ['Emily Watson',
#                   'Toby Kebbell',
#                   'Tom Hiddleston',
#                   'Benedict Cumberbatch',
#                   'Jeremy Irvine'],
#   'director_name': 'Steven Spielberg',
#   'movie_title': 'War Horse'},
#  {'actor_names': ['Dan Aykroyd',
#                   'Marisa Tomei',
#                   'John Cusack',
#                   'Joan Cusack',
#                   'Hilary Duff'],
#   'director_name': 'Joshua Seftel',
#   'movie_title': 'War, Inc.'},
#  {'actor_names': ['Dabney Coleman',
#                   'Matthew Broderick',
#                   'Ally Sheedy',
#                   'John Wood',
#                   'Barry Corbin'],
#   'director_name': 'John Badham',
#   'movie_title': 'WarGames'},
#  {'actor_names': ['Ben Foster',
#                   'Paula Patton',
#                   'Dominic Cooper',
#                   'Travis Fimmel',
#                   'Robert Kazinsky'],
#   'director_name': 'Duncan Jones',
#   'movie_title': 'Warcraft'},
#  {'actor_names': ['Mary Woronov',
#                   'Lori Singer',
#                   'Julian Sands',
#                   'Richard E. Grant',
#                   "Kevin O'Brien"],
#   'director_name': 'Steve Miner',
#   'movie_title': 'Warlock'},
#  {'actor_names': ['Julian Sands',
#                   'Chris Young',
#                   'Paula Marshall',
#                   'Joanna Pacula',
#                   'Steve Kahan'],
#   'director_name': 'Anthony Hickox',
#   'movie_title': 'Warlock: The Armageddon'},
#  {'actor_names': ['Orson Welles',
#                   'Rod Steiger',
#                   'Jack Hawkins',
#                   'Christopher Plummer',
#                   'Virginia McKenna'],
#   'director_name': 'Sergey Bondarchuk',
#   'movie_title': 'Waterloo'},
#  {'actor_names': ['Mel Gibson',
#                   'Sam Elliott',
#                   'Madeleine Stowe',
#                   'Greg Kinnear',
#                   'Chris Klein'],
#   'director_name': 'Randall Wallace',
#   'movie_title': 'We Were Soldiers'},
#  {'actor_names': ['Anna Faris',
#                   'Chris Evans',
#                   'Martin Freeman',
#                   'Ari Graynor',
#                   'Chris Pratt'],
#   'director_name': 'Mark Mylod',
#   'movie_title': "What's Your Number?"},
#  {'actor_names': ['Jamel Debbouze',
#                   'Arié Elmaleh',
#                   'Mélissa Theuriau',
#                   'Patrice Thibaud',
#                   'Christian Hecq'],
#   'director_name': 'Jamel Debbouze',
#   'movie_title': 'Why I Did (Not) Eat My Father'},
#  {'actor_names': ['Rupert Everett',
#                   'Bill Nighy',
#                   'Rupert Grint',
#                   'Eileen Atkins',
#                   'Emily Blunt'],
#   'director_name': 'Jonathan Lynn',
#   'movie_title': 'Wild Target'},
#  {'actor_names': ['M. Emmet Walsh',
#                   'Kevin Kline',
#                   'Kenneth Branagh',
#                   'Will Smith',
#                   'Salma Hayek'],
#   'director_name': 'Barry Sonnenfeld',
#   'movie_title': 'Wild Wild West'},
#  {'actor_names': ['Zane Holtz',
#                   'Glen Powell',
#                   'Kiowa Gordon',
#                   'Castille Landon',
#                   'Johnny Sequoyah'],
#   'director_name': 'Russell Friedenberg',
#   'movie_title': 'Wind Walkers'},
#  {'actor_names': ['Nicolas Cage',
#                   'Adam Beach',
#                   'Noah Emmerich',
#                   'Mark Ruffalo',
#                   'Peter Stormare'],
#   'director_name': 'John Woo',
#   'movie_title': 'Windtalkers'},
#  {'actor_names': ['Jürgen Prochnow',
#                   'Matthew Lillard',
#                   'Tchéky Karyo',
#                   'Freddie Prinze Jr.',
#                   'Saffron Burrows'],
#   'director_name': 'Christopher Roberts',
#   'movie_title': 'Wing Commander'},
#  {'actor_names': ['Martijn Lakemeier',
#                   'Melody Klaver',
#                   'Yorick van Wageningen',
#                   'Jamie Campbell Bower',
#                   'Raymond Thiry'],
#   'director_name': 'Martin Koolhoven',
#   'movie_title': 'Winter in Wartime'},
#  {'actor_names': ['Helen Mirren',
#                   'Katie Holmes',
#                   'Ryan Reynolds',
#                   'Tatiana Maslany',
#                   'Max Irons'],
#   'director_name': 'Simon Curtis',
#   'movie_title': 'Woman in Gold'},
#  {'actor_names': ['Rip Torn',
#                   'Michael Douglas',
#                   'Tobey Maguire',
#                   'Katie Holmes',
#                   'Frances McDormand'],
#   'director_name': 'Curtis Hanson',
#   'movie_title': 'Wonder Boys'},
#  {'actor_names': ['Halle Berry',
#                   'Hugh Jackman',
#                   'James McAvoy',
#                   'Jennifer Lawrence',
#                   'Michael Fassbender'],
#   'director_name': 'Bryan Singer',
#   'movie_title': 'X-Men: Days of Future Past'},
#  {'actor_names': ['Ranbir Kapoor',
#                   'Deepika Padukone',
#                   'Kalki Koechlin',
#                   'Aditya Roy Kapoor',
#                   'Kunaal Roy Kapur'],
#   'director_name': 'Ayan Mukherjee',
#   'movie_title': 'Yeh Jawaani Hai Deewani'},
#  {'actor_names': ['Marques Houston', 'Omarion', 'J-Boog', "Lil' Fizz", 'Raz B'],
#   'director_name': 'Chris Stokes',
#   'movie_title': 'You Got Served'},
#  {'actor_names': ['Sean Connery',
#                   'Akiko Wakabayashi',
#                   'Karin Dor',
#                   'Mie Hama',
#                   'Tetsurō Tamba'],
#   'director_name': 'Lewis Gilbert',
#   'movie_title': 'You Only Live Twice'},
#  {'actor_names': ['Tom Hanks',
#                   'Meg Ryan',
#                   'Parker Posey',
#                   'Greg Kinnear',
#                   'Katie Sagona'],
#   'director_name': 'Nora Ephron',
#   'movie_title': "You've Got Mail"},
#  {'actor_names': ['Milla Jovovich',
#                   'Ben Stiller',
#                   'Owen Wilson',
#                   'Will Ferrell',
#                   'Christine Taylor'],
#   'director_name': 'Ben Stiller',
#   'movie_title': 'Zoolander'},
#  {'actor_names': ['Forest Whitaker',
#                   'Orlando Bloom',
#                   'Conrad Kemp',
#                   'Inge Beckmann',
#                   'Tinarie Van Wyk-Loots'],
#   'director_name': 'Jérôme Salle',
#   'movie_title': 'Zulu'}]

# %% [markdown]
# # `GraphCypherQAChain` 클래스 사용
#
# - `from langchain_neo4j import GraphCypherQAChain`
#
# ## 기능
#
# `GraphCypherQAChain`은 자연어로 Neo4j 데이터베이스와 대화할 수 있도록 하는 체인이다. LLM과 DB 스키마를 활용해 사용자 질문을 Cypher 쿼리로 변환하고 이를 DB에 실행한다.
#
# 내부적으로 자연어를 cypher 쿼리로 만드는 것과 질문과 조회결과를 바탕으로 최종 답변을 생성할 것 두 단계로 실행된다.
#
# ```
# 사용자 자연어 질문
#     ↓ [1단계 LLM] 그래프 스키마 참고
# Cypher 쿼리 생성
#     ↓ Neo4j 실행
# 쿼리 결과 (컨텍스트)
#     ↓ [2단계 LLM] 컨텍스트 + 원래 질문
# 최종 자연어 답변
# ```
#
#
# ## 객체 생성 — `from_llm()` 클래스 메소드 사용
#
# - 객체 initializer 대신 **`from_llm()` 클래스 메소드**를 사용하여 생성한다.
#
#     ```python
#     chain = GraphCypherQAChain.from_llm(
#         llm=None,
#         *,
#         graph,                        # 필수
#         allow_dangerous_requests,     # 필수 (True 명시 필요)
#         qa_prompt=None,
#         cypher_prompt=None,
#         cypher_llm=None,
#         qa_llm=None,
#         exclude_types=[],
#         include_types=[],
#         validate_cypher=False,
#         qa_llm_kwargs=None,
#         cypher_llm_kwargs=None,
#         use_function_response=False,
#         function_response_system=...,
#         top_k=10,
#         return_intermediate_steps=False,
#         return_direct=False,
#         verbose=False,
#     )
#     ```
#
# ### 주요 파라미터 정리
#
# **필수 파라미터**
#
# | 파라미터 | 타입 | 설명 |
# |---|---|---|
# | `graph` | `Neo4jGraph` | 연결할 Neo4j 그래프 객체 |
# | `allow_dangerous_requests` | `bool` | `True` 필수. DB 변경 쿼리 허용에 대한 사용자 동의 명시 |
#
# **LLM 설정**
#
# | 파라미터 | 기본값 | 설명 |
# |---|---|---|
# | `llm` | `None` | Cypher 생성 + 답변 생성에 동일한 LLM 사용 |
# | `cypher_llm` | `None` | Cypher 생성 전용 LLM (llm과 중복 사용 불가) |
# | `qa_llm` | `None` | 답변 생성 전용 LLM (llm과 중복 사용 불가) |
#
# **프롬프트 커스터마이징**
#
# | 파라미터 | 기본값 | 설명 |
# |---|---|---|
# | `cypher_prompt` | (CYPHER_GENERATION_PROMPT) | Cypher 생성용 커스텀 프롬프트 (`{schema}`, `{question}` 변수 포함). 생략시 내장된 프롬프트 사용 |
# | `qa_prompt` | (CYPHER_QA_PROMPT) | 답변 생성용 커스텀 프롬프트. 생략시 내장된 프롬프트 사용 |
# | `function_response_system` | (FUNCTION_RESPONSE_SYSTEM) | `use_function_response=True` 일 때 시스템 메시지 |
#
# **스키마 필터링**
#
# | 파라미터 | 기본값 | 설명 |
# |---|---|---|
# | `include_types` | `[]` | LLM에 노출할 노드/관계 타입만 지정 |
# | `exclude_types` | `[]` | LLM에서 제외할 노드/관계 타입 지정 |
#
# **결과 제어**
#
# | 파라미터 | 기본값 | 설명 |
# |---|---|---|
# | `top_k` | `10` | 쿼리 결과를 LLM에 전달할 최대 건수 |
# | `return_intermediate_steps` | `False` | `True`이면 생성된 Cypher, 쿼리 결과도 함께 반환 |
# | `return_direct` | `False` | `True`이면 LLM 2단계 생략, DB 조회 결과를 직접 반환 |
# | `validate_cypher` | `False` | `True`이면 관계 방향 오류 등을 자동 교정 |
# | `use_function_response` | `False` | `True`이면 DB 결과를 tool/function 응답 형식으로 LLM에 전달 (정확도 향상) |
# | `verbose` | `False` | `True`이면 생성된 Cypher, 컨텍스트 등 중간 과정 출력 |
#
#
# ## 주요 메소드, 속성
#
# - `invoke()` — 질의응답 실행
#   - 기본 반환 값 구조
#      ```python
#      result = chain.invoke({"query": "Top Gun에 출연한 배우는?"})
#      print(result["result"])   # 최종 자연어 답변
#      ```
#
#   - `return_intermediate_steps=True` 시 반환 값 구조:
#
#      ```python
#      {
#         "query": "Top Gun에 출연한 배우는?",
#         "result": "Tom Cruise, Val Kilmer ...",
#         "intermediate_steps": [
#            {"query": "MATCH (a:Actor)-[:ACTED_IN]->(m:Movie) WHERE m.name='Top Gun' RETURN a.name"},
#            {"context": [{"a.name": "Tom Cruise"}, {"a.name": "Val Kilmer"}, ...]}
#         ]
#      }
#      ```
# ### 주요 속성
#
# | 속성 | 설명 |
# |---|---|
# | `graph_schema` | LLM에 전달되는 현재 그래프 스키마 문자열 |
# | `input_key` | 입력 키 (기본값: `"query"`) |
# | `output_key` | 출력 키 (기본값: `"result"`) |
#
# - Cypher/QA LLM 분리 + 커스텀 프롬프트 하기
#
#     ```python
#     from langchain_core.prompts import PromptTemplate
#
#     CYPHER_TEMPLATE = """스키마: {schema}
#     질문을 Cypher로만 변환해줘. 설명 없이 쿼리만 출력.
#     질문: {question}"""
#
#     chain = GraphCypherQAChain.from_llm(
#         graph=graph,
#         cypher_llm=ChatOpenAI(model="gpt-4o-mini", temperature=0),  # Cypher 생성 전용
#         qa_llm=ChatOpenAI(model="gpt-4o", temperature=0),           # 답변 생성 전용
#         cypher_prompt=PromptTemplate(
#             input_variables=["schema", "question"],
#             template=CYPHER_TEMPLATE
#         ),
#         top_k=5,
#         return_intermediate_steps=True,
#         validate_cypher=True,
#         allow_dangerous_requests=True,
#     )
#     ```

# %%
# GraphCypherQAChain 이 사용하는 프롬프트 조회
from langchain_neo4j.chains.graph_qa.cypher import (
    CYPHER_GENERATION_PROMPT,   # 기본 Cypher 생성 프롬프트: 자연어 -> cypher 쿼리 생성 프롬프트
    CYPHER_QA_PROMPT,           # 기본 QA 프롬프트 : cypher 결과 -> 자연어로 변환시 사용할 프롬프트
)
from langchain_core.prompts import PromptTemplate

print(type(CYPHER_GENERATION_PROMPT), type(CYPHER_QA_PROMPT))
# print(CYPHER_GENERATION_PROMPT.template)
# print("="*50)
# print(CYPHER_QA_PROMPT.template)

################################################
# 사용자 정의 프롬프트 생성 
# - 기존 프롬프트를 수정하는 방식으로 만든다.
################################################
custom_prompt_str = CYPHER_GENERATION_PROMPT.template+\
"""
<constraint>
- When filtering by date, convert the data to the `date` type for processing.
</constraint>
"""

custom_cypher_template = PromptTemplate(template=custom_prompt_str)
print(custom_cypher_template.input_variables)

# %%
#################################
# CypherChain생성
#################################
from langchain_openai import ChatOpenAI
from langchain_neo4j import GraphCypherQAChain

llm = ChatOpenAI(model="gpt-5.4-mini", temperature=0.0)

cypher_chain = GraphCypherQAChain.from_llm(
    llm=llm, 
    graph=graph, 
    allow_dangerous_requests=True,
    verbose=True,
    cypher_prompt=custom_cypher_template # PromptTemplate 
)

# %%
print(cypher_chain.graph_schema)
print("--------------입/출력 key-------------------")
print(cypher_chain.input_key,"/", cypher_chain.output_key)

# %% [markdown]
# ## 쿼리 실행

# %%
answer = cypher_chain.invoke({"query": "영화 'Apollo 13'에 대한 정보를 알려주세요."})

# %%
print(answer)

# %%
from pprint import pprint
pprint(answer['result'])

# %%
answer = cypher_chain.invoke({"query":"Apollo 13에 출연한 배우이름과 그들이 출연한 다른 영화들을 조회해 주세요."})

# %%
print(answer["result"])

# %%
answer = cypher_chain.invoke({"query": "'Christopher Nolan' 감독의 영화를 모두 찾아주세요."})

# %%
print(answer)

# %%
pprint(answer['result'])

# %%
answer = cypher_chain.invoke({"query": "'Tom Hanks'가 출연한, 평점이 가장 높은 영화 3개는 무엇인가요? 영화제목과 평점을 알려주세요."})

# %%
print(answer)

# %%
pprint(answer['result'])

# %%
answer = cypher_chain.invoke({"query": "2000년 이후 개봉한 'Drama' 장르 영화 중 평점이 높은 순서로 5개를 영화제목, 개봉일자, 평점항목을 알려주세요."})

# %%
print(answer)

# %%
pprint(answer['result'])

# %% [markdown]
# ### 출력 갯수를 지정 (top k)

# %%
cypher_chain = GraphCypherQAChain.from_llm(
    llm=llm,
    graph=graph, 
    allow_dangerous_requests=True,
    verbose=True,
    
    top_k=5,                         # 최대 5개의 결과만 반환
)

answer = cypher_chain.invoke({"query": "'Tom Hanks' 배우가 출연한 영화를 모두 알려주세요."})

# %%
# LLM 답변 출력
pprint(answer['result'])

# %% [markdown]
# ### 생성된 cypher쿼리 포함 반환
#
# - `return_intermediate_steps`=True

# %%
cypher_chain = GraphCypherQAChain.from_llm(
    llm=llm,
    graph=graph, 
    allow_dangerous_requests=True,
    verbose=True,
    return_intermediate_steps=True  # 생성된 Cypher 쿼리와 중간 결과 확인
)

answer = cypher_chain.invoke({"query": "평점이 8점 이상인 'Action' 장르 영화는 무엇이 있나요?"})

# %%
for k, v in answer.items():
    print(f"{k}: {v}")

# %% [markdown]
# ### Neo4j DB 반환결과만 얻기
#
# - `return_direct`=True
# - cypher 쿼리 실행 결과를 바탕으로 LLM이 응답메세지를 만들어 반환하는데 `return_direct=True` 로 하면 cypher 쿼리 결과를 그대로 dictionary로 반환한다.

# %%
# 직접 Cypher 결과 얻기 (LLM 답변 없이)
cypher_chain = GraphCypherQAChain.from_llm(
    llm=llm,
    graph=graph, 
    allow_dangerous_requests=True,
    verbose=True,
    return_direct=True   # LLM 답변 생성 단계 건너뛰기
)

answer = cypher_chain.invoke({"query": "2000년대(2000-01-01 ~ 2009-12-31) 개봉한 영화를 평점 순으로 정렬해주세요."})

# %%
for k, v in answer.items():
    print(f"{k}: {v}")

# %%
import pandas as pd
pd.DataFrame([item for item in answer['result']])

# %% [markdown]
# ### cypher 쿼리 생성 모델과 최종 답변 생성 모델을 다르게 적용

# %%
cypher_llm = ChatOpenAI(model="gpt-5.4-mini", temperature=0.0)
qa_llm = ChatOpenAI(model="gpt-5.5", temperature=0.0)

cypher_chain = GraphCypherQAChain.from_llm(
    cypher_llm=cypher_llm,  # Cypher 쿼리 생성용 LLM
    qa_llm=qa_llm,          # 최종 답변 생성용 LLM
    
    graph=graph, 
    allow_dangerous_requests=True,
    verbose=True,
)

answer = cypher_chain.invoke({"query": "배우 'Leonardo DiCaprio'와 감독 'Christopher Nolan'이 함께 작업한 영화가 있나요?"})

# %%
for k, v in answer.items():
    print(f"{k}: {v}")
